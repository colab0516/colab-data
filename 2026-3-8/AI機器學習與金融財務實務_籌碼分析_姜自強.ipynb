# %% [markdown]
# # 掛載雲端硬碟

# %%
# 掛載雲端硬碟
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 📘Colab 進行matplotlib繪圖時顯示繁體中文

# %%
# 下載台北黑體字型（Google Drive 公開字型）
# !wget -O TaipeiSansTCBeta-Regular.ttf https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_&export=download

import matplotlib.font_manager as fm
import matplotlib.pyplot as plt

# 將字型加入 matplotlib
fm.fontManager.addfont('TaipeiSansTCBeta-Regular.ttf')
plt.rc('font', family='Taipei Sans TC Beta')

# 解決負號無法顯示問題
plt.rcParams['axes.unicode_minus'] = False
# Out:
# --2026-03-07 06:59:10--  https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_
# Resolving drive.google.com (drive.google.com)... 173.194.212.100, 173.194.212.102, 173.194.212.113, ...
# Connecting to drive.google.com (drive.google.com)|173.194.212.100|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_ [following]
# --2026-03-07 06:59:11--  https://drive.usercontent.google.com/download?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 172.217.203.132, 2607:f8b0:400c:c07::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|172.217.203.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20659344 (20M) [application/octet-stream]
# Saving to: ‘TaipeiSansTCBeta-Regular.ttf’
#
# TaipeiSansTCBeta-Re 100%[===================>]  19.70M  42.2MB/s    in 0.5s
#
# 2026-03-07 06:59:13 (42.2 MB/s) - ‘TaipeiSansTCBeta-Regular.ttf’ saved [20659344/20659344]

# %% [markdown]
# /content/drive/MyDrive/Colab Notebooks/TEJ2026A

# %% [markdown]
# /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026-20260307T040057Z-1-001.zip

# %%
# 請幫我解壓縮 /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026-20260307T040057Z-1-001.zip 這的 壓縮檔 ,存到 /content/drive/MyDrive/Colab Notebooks/TEJ2026A 資料夾
# !unzip "/content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026-20260307T040057Z-1-001.zip" -d "/content/drive/MyDrive/Colab Notebooks/TEJ2026A"
# Out:
# Archive:  /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026-20260307T040057Z-1-001.zip
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借劵餘額S6770力積電20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/當日沖銷S1504東元20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/融資融券S6443元晶20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券餘額S7769鴻勁20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/當日沖銷S7769鴻勁20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券成交S3563牧德20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/融資融券S2404漢唐20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/融資融券S7769鴻勁20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S6789采鈓20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/當日沖銷S2603長榮20260226.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/融資融劵S5274信驊20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券成交S7769鴻勁20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券成交S6443元晶20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券餘額S2603長榮20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S2603長榮20260226.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S2886兆豐金20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/融資融劵S2603長榮20260226.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S3017奇鋐2026.03.07.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券成交S2603長榮20260226.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/當日沖銷S6443元晶20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券餘額S2303聯電20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券餘額S3563牧德20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/當日沖銷S2408南亞科20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S2615萬海20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借卷成交S6505台塑化20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借劵餘額S2603長榮20260226.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券成交S3443創意20260226.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S3443創意20260226.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S3037欣興2026.03.07.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S2382廣達2026.03.07.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券餘額S2498宏達電20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借劵餘額S3324雙鴻20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券餘額S4417金洲20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S6443元晶20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/融資融券S2603長榮20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券餘額S6443元晶20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券成交S2408南亞科20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/當日沖銷S3324雙鴻20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券餘額S2408南亞科20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券餘額S1519華城20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券成交S1519華城20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券成交S3324雙鴻20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/融資融券S3563牧德20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/當日沖銷S4417金洲20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券成交S2603長榮20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借劵餘額S3443創意20260226.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券成交S2377微星20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借卷餘額S6505台塑化20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S3324雙鴻20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/融資融劵S3324雙鴻20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券餘額S1504東元20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/當日沖銷S2303聯電20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券餘額S2377微星20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券成交S1504東元20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/融資融券S2408南亞科20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/當日沖銷S1519華城20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S2002中鋼20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/當日沖銷S2498宏達電20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借劵成交S5274信驊20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/融資融劵S2732六角20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/當日沖銷S2002中鋼20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/當日沖銷S2732六角20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券成交S1101台泥20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券成交S2732六角20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借劵餘額S1101台泥20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/當日沖銷S2377微星20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/融資融券S1519華城20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借劵餘額S2732六角20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券成交S1216統一20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/融資融劵S1101台泥20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S2732六角20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券餘額S2404漢唐20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借劵餘額S5274信驊20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/融資融券S1504東元20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S1519華城20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/融資融券S2377微星20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/當日沖銷S1101台泥20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券成交S8261富鼎20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券餘額S8261富鼎20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/融資融劵S6789采鈓20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/當日沖銷S6505台塑化20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券餘額S1216統一20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/融資融券S1216統一20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S1101台泥20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/當日沖銷S2201裕隆20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S2201裕隆20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券成交S2404漢唐20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S6770力積電20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/融資融劵S3443創意-KY20260226.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/當日沖銷S3443創意20260226.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/當日沖銷S1216統一20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券餘額S2201裕隆20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/融資融券S2201裕隆20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/融資融券S2303聯電20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/融資融劵S6770力積電20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/當日沖銷S2404漢唐20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/當日沖銷S5274信驊20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借卷餘額S2645長榮航太20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借卷成交S2645長榮航太20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S1504東元20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/融資融劵S2002中鋼20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/融資融劵S2317鴻海20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借劵餘額S6789采鈓20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/融資融劵S2049上銀20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券成交S2201裕隆20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/當日沖銷S2645長榮航太20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券成交S6789采鈓20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借劵成交S2002中鋼20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/融資融券S8261富鼎20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/當日沖銷S8261富鼎20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借劵成交S6770力積電20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/融資融劵S2308台達電20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/融資融卷S2645長榮航太20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券成交S2449京元電子20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S2404漢唐20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/融資融券S4417金洲20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S3653健策20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借劵餘額S2002中鋼20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/當日沖銷S0050元大台灣20260306 - 副本.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S2408南亞科20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借劵成交S2912統一超20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S7769鴻勁20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S3661世芯-KY20260226.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借劵餘額S2049上銀20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/融資融劵S3661世芯-KY20260226.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借劵餘額S2308台達電20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S9921巨大20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/融資融券S2498宏達電20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借劵餘額S2317鴻海20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借劵成交S2337旺宏20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券成交S2317鴻海20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借劵餘額S2337旺宏20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S2377微星20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/當日沖銷S3661世芯-KY20260226.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券成交S2308台達電20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/當日沖銷S0050元大台灣20260306 - 副本(1).xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/融資融券S2449京元電子20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借劵餘額S2912統一超20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/當日沖銷S2337旺宏20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券成交S2049上銀20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券餘額S2449京元電子20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S6669緯穎20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S2363矽統20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/當日沖銷S2317鴻海20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/當日沖銷S6789采鈓20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/當日沖銷S6770力機電20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/融資融卷S1503士電20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/當日沖銷S2308台達電20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/當日沖銷S2455全新20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/融資融卷S6505台塑化20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券成交S2002中鋼20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/當日沖銷S2049上銀20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借劵餘額S3661世芯-KY20260226.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/當日沖銷S2449京元電子20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券成交S2455全新20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S2303聯電20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券成交S2618長榮航20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/融資融劵S2912統一超20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借卷成交S1717長興20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券餘額S2002中鋼20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券餘額S2618長榮航20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S2308台達電20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/當日沖銷S2912統一超20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券成交S2330台積電20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券餘額Y9999加權指數20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/當日沖銷S2603長榮20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/融資融劵S2337旺宏20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券餘額S0050元大台灣20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券餘額S2455全新20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券餘額S1717長興20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S2498宏達電20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券餘額S2330台積電20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S6526達發20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/當日沖銷交易統計資訊S1717長興20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券成交S3661世芯-KY20260226.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借卷成交S2317鴻海20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/當日沖銷交易統計資訊S2317鴻海20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S2645長榮航太20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/當日沖銷Y9999加權指數20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/當日沖銷S2330台積電20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/融資融卷S2317鴻海20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/融資融券S2618長榮航20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S2327國巨20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券餘額S2317鴻海20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/當日沖銷S3563牧德20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S2337旺宏20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/融資融券S2002中鋼20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/融資融卷S1717長興20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/融資融券S2455全新20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/當日沖銷S2618長榮航20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S2455全新20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/融資融券S2330台積電20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S6415矽力KY20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S4772台特化20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S2454聯發科20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/融資融券Y9999加權指數20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S2618長榮航20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S2449京元電20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S2603長榮20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超Y9999加權指數20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S2912統一超20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/當日沖銷S2330台積電20260226.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S2354鴻準20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/融資融劵S2330台積電20260226.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S4417金洲20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S1503士電20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借劵餘額Y9999加權指數20260226.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S5274信驊20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S8261富鼎20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S1216統一20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S2049上銀20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超 S3481 群創20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/當日沖銷Y9999加權指數20260226.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超Y9999加權指數20260226.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/融資融劵Y9999加權指數20260226.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S3563牧德20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S3576聯合再生20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借劵餘額S2330台積電20260226.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S2330台積電20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S2330台積電20260226.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/df_taiex_finalA.csv
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S1717長興20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券成交S2330台積電20260226.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S6505台塑化20260306.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S2330台積電20260209.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超Y9999加權指數20260209.xlsx
#   inflating: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S2317鴻海20260306.xlsx

# %%
import os

path = "/content/drive/MyDrive/Colab Notebooks/TEJ2026A"
target = "2330"

# 遍歷資料夾並尋找包含 2330 的檔案
files_with_2330 = []
for root, dirs, files in os.walk(path):
    for file in files:
        if target in file:
            files_with_2330.append(os.path.join(root, file))

# 顯示結果
if files_with_2330:
    print(f"找到以下包含 '{target}' 的檔案：")
    for f in files_with_2330:
        print(f)
else:
    print(f"在 {path} 中找不到包含 '{target}' 的檔案。")
# Out:
# 找到以下包含 '2330' 的檔案：
# /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券成交S2330台積電20260306.xlsx
# /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券餘額S2330台積電20260306.xlsx
# /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/當日沖銷S2330台積電20260306.xlsx
# /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/融資融券S2330台積電20260306.xlsx
# /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/當日沖銷S2330台積電20260226.xlsx
# /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/融資融劵S2330台積電20260226.xlsx
# /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借劵餘額S2330台積電20260226.xlsx
# /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S2330台積電20260306.xlsx
# /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S2330台積電20260226.xlsx
# /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/借券成交S2330台積電20260226.xlsx
# /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S2330台積電20260209.xlsx

# %%
# 請輸入以下 /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S2330台積電20260306.xlsx 檔案, 存成 majorTraded 變數( 省略前 2 rows)
# 讀取 Excel 檔案並跳過前兩列，存成 majorTraded 變數
import pandas as pd

file_path = "/content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/三大法人買賣超S2330台積電20260306.xlsx"
majorTraded = pd.read_excel(file_path, skiprows=2)

# 顯示前幾列以確認讀取成功
display(majorTraded.head())
# Out:
#           年月日  外資買賣超(千股)  外資買賣超市值(百萬)  外資總投資股數(千股)  外資總投資市值(百萬)  投信買賣超(千股)  \
# 0  2026/03/06     -10927    -20652.03     18558913  35076345.16        911
# 1  2026/03/05      -9756    -18536.40     18572138  35287062.91       1494
# 2  2026/03/04     -27354    -51015.21     18586949  34664660.15       1467
# 3  2026/03/03     -21195    -41012.33     18619872  36029452.50       1279
# 4  2026/03/02     -19539    -38589.53     18643625  36821159.89       2624
#
#    投信買賣超市值(百萬)  投信持股數(千股)  投信持股數市值(百萬)  自營買賣超(千股)  ...  自營自行買賣超(千股)  \
# 0      1721.79     722925   1366328.25        866  ...          194
# 1      2838.60     722016   1371830.40        118  ...         -666
# 2      2735.96     720520   1343769.80        799  ...        -1130
# 3      2474.87     719054   1391369.49        897  ...         -132
# 4      5182.40     717775   1417605.63        514  ...          104
#
#    自營自行買賣超(百萬)  自營避險買賣超(千股)  自營避險買賣超(百萬)  自營持股數(千股)  自營持股數市值(百萬)  合計買賣超(千股)  \
# 0     366660.0          672    1270080.0      40382     76321.98      -9150
# 1   -1265400.0          784    1489600.0      39516     75080.40      -8144
# 2   -2107450.0         1929    3597585.0      39398     73477.27     -25089
# 3    -255420.0         1029    1991115.0      38599     74689.07     -19020
# 4     205400.0          410     809750.0      37702     74461.45     -16401
#
#    合計買賣超市值(百萬)  合計持股數(千股)  合計持股數市值(百萬)
# 0    -17293.50   19322220  36518995.39
# 1    -15473.60   19333670  36733973.71
# 2    -46790.99   19346867  36081907.22
# 3    -36803.70   19377525  37495511.05
# 4    -32391.98   19399102  38313226.96
#
# [5 rows x 21 columns]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
majorTraded
# Out:
#              年月日  外資買賣超(千股)  外資買賣超市值(百萬)  外資總投資股數(千股)  外資總投資市值(百萬)  投信買賣超(千股)  \
# 0     2026/03/06     -10927    -20652.03     18558913  35076345.16        911
# 1     2026/03/05      -9756    -18536.40     18572138  35287062.91       1494
# 2     2026/03/04     -27354    -51015.21     18586949  34664660.15       1467
# 3     2026/03/03     -21195    -41012.33     18619872  36029452.50       1279
# 4     2026/03/02     -19539    -38589.53     18643625  36821159.89       2624
# ...          ...        ...          ...          ...          ...        ...
# 2715  2015/01/09     -32026     -4291.48     19991382   2678845.19      -1495
# 2716  2015/01/08       7797      1075.99     20023409   2763230.44         86
# 2717  2015/01/07       1525       204.35     20014812   2681984.81      -1341
# 2718  2015/01/06     -37077     -4949.78     20013287   2671773.81      -1212
# 2719  2015/01/05       3685       514.06     20050364   2797025.78       -752
#
#       投信買賣超市值(百萬)  投信持股數(千股)  投信持股數市值(百萬)  自營買賣超(千股)  ...  自營自行買賣超(千股)  \
# 0         1721.79     722925   1366328.25        866  ...          194
# 1         2838.60     722016   1371830.40        118  ...         -666
# 2         2735.96     720520   1343769.80        799  ...        -1130
# 3         2474.87     719054   1391369.49        897  ...         -132
# 4         5182.40     717775   1417605.63        514  ...          104
# ...           ...        ...          ...        ...  ...          ...
# 2715      -200.33     240627     32244.02        -13  ...        -1376
# 2716        11.87     242122     33412.84       -624  ...         -233
# 2717      -179.69     242036     32432.82       1386  ...          940
# 2718      -161.80     243377     32490.83       3307  ...         2451
# 2719      -104.90     244589     34120.17        545  ...         -178
#
#       自營自行買賣超(百萬)  自營避險買賣超(千股)  自營避險買賣超(百萬)  自營持股數(千股)  自營持股數市值(百萬)  \
# 0        366660.0          672    1270080.0      40382     76321.98
# 1      -1265400.0          784    1489600.0      39516     75080.40
# 2      -2107450.0         1929    3597585.0      39398     73477.27
# 3       -255420.0         1029    1991115.0      38599     74689.07
# 4        205400.0          410     809750.0      37702     74461.45
# ...           ...          ...          ...        ...          ...
# 2715    -184384.0         1363     182642.0      15394      2062.80
# 2716     -32154.0         -391     -53958.0      15407      2126.17
# 2717     125960.0          446      59764.0      16031      2148.15
# 2718     327208.5          856     114276.0      14645      1955.11
# 2719     -24831.0          723     100858.5      11338      1581.65
#
#       合計買賣超(千股)  合計買賣超市值(百萬)  合計持股數(千股)  合計持股數市值(百萬)
# 0         -9150    -17293.50   19322220  36518995.39
# 1         -8144    -15473.60   19333670  36733973.71
# 2        -25089    -46790.99   19346867  36081907.22
# 3        -19020    -36803.70   19377525  37495511.05
# 4        -16401    -32391.98   19399102  38313226.96
# ...         ...          ...        ...          ...
# 2715     -33534     -4493.56   20247403   2713152.00
# 2716       7259      1001.74   20280938   2798769.44
# 2717       1570       210.38   20272879   2716565.79
# 2718     -34982     -4670.10   20271309   2706219.75
# 2719       3478       485.18   20306291   2832727.59
#
# [2720 rows x 21 columns]

# %%
# 顯示 majorTraded 欄位名稱
majorTraded.columns
# Out:
# Index(['年月日', '外資買賣超(千股)', '外資買賣超市值(百萬)', '外資總投資股數(千股)', '外資總投資市值(百萬)',
#        '投信買賣超(千股)', '投信買賣超市值(百萬)', '投信持股數(千股)', '投信持股數市值(百萬)', '自營買賣超(千股)',
#        '自營買賣超市值(百萬)', '自營自行買賣超(千股)', '自營自行買賣超(百萬)', '自營避險買賣超(千股)',
#        '自營避險買賣超(百萬)', '自營持股數(千股)', '自營持股數市值(百萬)', '合計買賣超(千股)', '合計買賣超市值(百萬)',
#        '合計持股數(千股)', '合計持股數市值(百萬)'],
#       dtype='object')

# %%
# 顯示 majorTraded 基本資訊
# 顯示 majorTraded 基本資訊 (包含資料型態與缺失值狀況)
majorTraded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2720 entries, 0 to 2719
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   年月日          2720 non-null   object
#  1   外資買賣超(千股)    2720 non-null   int64
#  2   外資買賣超市值(百萬)  2720 non-null   float64
#  3   外資總投資股數(千股)  2720 non-null   int64
#  4   外資總投資市值(百萬)  2720 non-null   float64
#  5   投信買賣超(千股)    2720 non-null   int64
#  6   投信買賣超市值(百萬)  2720 non-null   float64
#  7   投信持股數(千股)    2720 non-null   int64
#  8   投信持股數市值(百萬)  2720 non-null   float64
#  9   自營買賣超(千股)    2720 non-null   int64
#  10  自營買賣超市值(百萬)  2720 non-null   float64
#  11  自營自行買賣超(千股)  2720 non-null   int64
#  12  自營自行買賣超(百萬)  2720 non-null   float64
#  13  自營避險買賣超(千股)  2720 non-null   int64
#  14  自營避險買賣超(百萬)  2720 non-null   float64
#  15  自營持股數(千股)    2720 non-null   int64
#  16  自營持股數市值(百萬)  2720 non-null   float64
#  17  合計買賣超(千股)    2720 non-null   int64
#  18  合計買賣超市值(百萬)  2720 non-null   float64
#  19  合計持股數(千股)    2720 non-null   int64
#  20  合計持股數市值(百萬)  2720 non-null   float64
# dtypes: float64(10), int64(10), object(1)
# memory usage: 446.4+ KB

# %%
# 顯示 majorTraded 敘述性統計
# 顯示 majorTraded 敘述性統計
majorTraded.describe()
# Out:
#            外資買賣超(千股)   外資買賣超市值(百萬)   外資總投資股數(千股)   外資總投資市值(百萬)    投信買賣超(千股)  \
# count    2720.000000   2720.000000  2.720000e+03  2.720000e+03  2720.000000
# mean     -468.939338   -400.139254  1.964821e+07  9.303322e+06    62.378309
# std     12668.441818   7173.322687  6.706388e+05  6.639355e+06   625.614588
# min    -71035.000000 -51015.210000  1.832910e+07  2.258742e+06 -4966.000000
# 25%     -6125.500000  -2242.805000  1.905713e+07  4.439024e+06  -174.500000
# 50%       -49.000000    -20.775000  1.971463e+07  7.193600e+06    18.000000
# 75%      5750.000000   2016.492500  2.020748e+07  1.154411e+07   275.250000
# max    112956.000000  70710.460000  2.079982e+07  3.764663e+07  5322.000000
#
#        投信買賣超市值(百萬)      投信持股數(千股)   投信持股數市值(百萬)     自營買賣超(千股)  自營買賣超市值(百萬)  \
# count  2720.000000    2720.000000  2.720000e+03   2720.000000  2720.000000
# mean     69.635853  289922.856250  1.817532e+05     57.983088    60.203022
# std     510.953680  145220.433923  2.318338e+05   1264.704099   752.539455
# min   -6321.420000  101877.000000  2.159792e+04 -12026.000000 -7666.710000
# 25%     -56.460000  161175.000000  3.554994e+04   -437.000000  -147.362500
# 50%       5.085000  244597.000000  8.393127e+04     50.000000    15.575000
# 75%     110.777500  423637.000000  2.312457e+05    556.250000   217.450000
# max    7663.680000  722925.000000  1.438607e+06  11898.000000  6175.060000
#
#         自營自行買賣超(千股)   自營自行買賣超(百萬)  自營避險買賣超(千股)   自營避險買賣超(百萬)     自營持股數(千股)  \
# count   2720.000000  2.720000e+03  2720.000000  2.720000e+03   2720.000000
# mean      10.461397  1.534073e+04    47.529044  4.486849e+04  17464.573162
# std      870.090828  5.169876e+05   590.436724  3.435392e+05  12943.771638
# min    -8379.000000 -4.901715e+06 -4635.000000 -3.623490e+06      0.000000
# 25%     -283.250000 -1.004142e+05  -191.000000 -6.733075e+04   6045.750000
# 50%        8.000000  2.298750e+03    30.000000  9.293000e+03  15480.000000
# 75%      303.250000  1.094900e+05   299.250000  1.128146e+05  27362.000000
# max    10431.000000  5.413689e+06  4274.000000  4.333665e+06  52029.000000
#
#         自營持股數市值(百萬)      合計買賣超(千股)   合計買賣超市值(百萬)     合計持股數(千股)   合計持股數市值(百萬)
# count   2720.000000    2720.000000   2720.000000  2.720000e+03  2.720000e+03
# mean   10999.677614    -348.587132   -270.310551  1.995559e+07  9.496075e+06
# std    14167.398110   12598.823293   7102.428375  5.531571e+05  6.873248e+06
# min        0.000000  -71321.000000 -47465.490000  1.875914e+07  2.303430e+06
# 25%     1342.330000   -5890.500000  -2115.937500  1.955587e+07  4.471840e+06
# 50%     4425.515000      86.500000     26.690000  2.000360e+07  7.327548e+06
# 75%    17196.877500    5674.000000   1992.407500  2.042231e+07  1.170110e+07
# max    76321.980000  115039.000000  72014.410000  2.093888e+07  3.915763e+07

# %% [markdown]
# # 🚀 台積電三大法人量化分析 AI Notebook

# %% [markdown]
# ## 📊 Step 0 — Colab 環境初始化

# %%
# ================================
# TEJ Financial Data Analysis
# Data Cleaning Pipeline
# ================================
'''
from google.colab import drive
drive.mount('/content/drive')
'''

import os
BASE_PATH = "/content/drive/MyDrive/Colab Notebooks/TEJ2026A"
os.chdir(BASE_PATH)

print("Current Working Directory:", os.getcwd())

# 基本套件
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("seaborn-v0_8")
# Out:
# Current Working Directory: /content/drive/MyDrive/Colab Notebooks/TEJ2026A

# %% [markdown]
# ## 📊 Step 1 — 基本資料結構檢查

# %%
print("===== Data Shape =====")
print(majorTraded.shape)

print("\n===== Column Names =====")
print(majorTraded.columns)

print("\n===== Data Types =====")
print(majorTraded.dtypes)

print("\n===== Preview =====")
majorTraded.head()
# Out:
# ===== Data Shape =====
# (2720, 21)
#
# ===== Column Names =====
# Index(['年月日', '外資買賣超(千股)', '外資買賣超市值(百萬)', '外資總投資股數(千股)', '外資總投資市值(百萬)',
#        '投信買賣超(千股)', '投信買賣超市值(百萬)', '投信持股數(千股)', '投信持股數市值(百萬)', '自營買賣超(千股)',
#        '自營買賣超市值(百萬)', '自營自行買賣超(千股)', '自營自行買賣超(百萬)', '自營避險買賣超(千股)',
#        '自營避險買賣超(百萬)', '自營持股數(千股)', '自營持股數市值(百萬)', '合計買賣超(千股)', '合計買賣超市值(百萬)',
#        '合計持股數(千股)', '合計持股數市值(百萬)'],
#       dtype='object')
#
# ===== Data Types =====
# 年月日             object
# 外資買賣超(千股)        int64
# 外資買賣超市值(百萬)    float64
# 外資總投資股數(千股)      int64
# 外資總投資市值(百萬)    float64
# 投信買賣超(千股)        int64
# 投信買賣超市值(百萬)    float64
# 投信持股數(千股)        int64
# 投信持股數市值(百萬)    float64
# 自營買賣超(千股)        int64
# 自營買賣超市值(百萬)    float64
# 自營自行買賣超(千股)      int64
# 自營自行買賣超(百萬)    float64
# 自營避險買賣超(千股)      int64
# 自營避險買賣超(百萬)    float64
# 自營持股數(千股)        int64
# 自營持股數市值(百萬)    float64
# 合計買賣超(千股)        int64
# 合計買賣超市值(百萬)    float64
# 合計持股數(千股)        int64
# 合計持股數市值(百萬)    float64
# dtype: object
#
# ===== Preview =====
#           年月日  外資買賣超(千股)  外資買賣超市值(百萬)  外資總投資股數(千股)  外資總投資市值(百萬)  投信買賣超(千股)  \
# 0  2026/03/06     -10927    -20652.03     18558913  35076345.16        911
# 1  2026/03/05      -9756    -18536.40     18572138  35287062.91       1494
# 2  2026/03/04     -27354    -51015.21     18586949  34664660.15       1467
# 3  2026/03/03     -21195    -41012.33     18619872  36029452.50       1279
# 4  2026/03/02     -19539    -38589.53     18643625  36821159.89       2624
#
#    投信買賣超市值(百萬)  投信持股數(千股)  投信持股數市值(百萬)  自營買賣超(千股)  ...  自營自行買賣超(千股)  \
# 0      1721.79     722925   1366328.25        866  ...          194
# 1      2838.60     722016   1371830.40        118  ...         -666
# 2      2735.96     720520   1343769.80        799  ...        -1130
# 3      2474.87     719054   1391369.49        897  ...         -132
# 4      5182.40     717775   1417605.63        514  ...          104
#
#    自營自行買賣超(百萬)  自營避險買賣超(千股)  自營避險買賣超(百萬)  自營持股數(千股)  自營持股數市值(百萬)  合計買賣超(千股)  \
# 0     366660.0          672    1270080.0      40382     76321.98      -9150
# 1   -1265400.0          784    1489600.0      39516     75080.40      -8144
# 2   -2107450.0         1929    3597585.0      39398     73477.27     -25089
# 3    -255420.0         1029    1991115.0      38599     74689.07     -19020
# 4     205400.0          410     809750.0      37702     74461.45     -16401
#
#    合計買賣超市值(百萬)  合計持股數(千股)  合計持股數市值(百萬)
# 0    -17293.50   19322220  36518995.39
# 1    -15473.60   19333670  36733973.71
# 2    -46790.99   19346867  36081907.22
# 3    -36803.70   19377525  37495511.05
# 4    -32391.98   19399102  38313226.96
#
# [5 rows x 21 columns]

# %% [markdown]
# 專業分析師第一步一定確認：
#
# - 資料筆數
# - 欄位型態
# - 欄位名稱

# %% [markdown]
# ## 📊 Step 2 — 日期格式處理
#
# TEJ資料通常是 字串日期

# %%
majorTraded['年月日'] = pd.to_datetime(majorTraded['年月日'])

majorTraded = majorTraded.sort_values('年月日')

majorTraded.set_index('年月日', inplace=True)

majorTraded.head()
# Out:
#             外資買賣超(千股)  外資買賣超市值(百萬)  外資總投資股數(千股)  外資總投資市值(百萬)  投信買賣超(千股)  \
# 年月日
# 2015-01-05       3685       514.06     20050364   2797025.78       -752
# 2015-01-06     -37077     -4949.78     20013287   2671773.81      -1212
# 2015-01-07       1525       204.35     20014812   2681984.81      -1341
# 2015-01-08       7797      1075.99     20023409   2763230.44         86
# 2015-01-09     -32026     -4291.48     19991382   2678845.19      -1495
#
#             投信買賣超市值(百萬)  投信持股數(千股)  投信持股數市值(百萬)  自營買賣超(千股)  自營買賣超市值(百萬)  \
# 年月日
# 2015-01-05      -104.90     244589     34120.17        545        76.03
# 2015-01-06      -161.80     243377     32490.83       3307       441.48
# 2015-01-07      -179.69     242036     32432.82       1386       185.72
# 2015-01-08        11.87     242122     33412.84       -624       -86.11
# 2015-01-09      -200.33     240627     32244.02        -13        -1.74
#
#             自營自行買賣超(千股)  自營自行買賣超(百萬)  自營避險買賣超(千股)  自營避險買賣超(百萬)  自營持股數(千股)  \
# 年月日
# 2015-01-05         -178     -24831.0          723     100858.5      11338
# 2015-01-06         2451     327208.5          856     114276.0      14645
# 2015-01-07          940     125960.0          446      59764.0      16031
# 2015-01-08         -233     -32154.0         -391     -53958.0      15407
# 2015-01-09        -1376    -184384.0         1363     182642.0      15394
#
#             自營持股數市值(百萬)  合計買賣超(千股)  合計買賣超市值(百萬)  合計持股數(千股)  合計持股數市值(百萬)
# 年月日
# 2015-01-05      1581.65       3478       485.18   20306291   2832727.59
# 2015-01-06      1955.11     -34982     -4670.10   20271309   2706219.75
# 2015-01-07      2148.15       1570       210.38   20272879   2716565.79
# 2015-01-08      2126.17       7259      1001.74   20280938   2798769.44
# 2015-01-09      2062.80     -33534     -4493.56   20247403   2713152.00

# %%
majorTraded
# Out:
#             外資買賣超(千股)  外資買賣超市值(百萬)  外資總投資股數(千股)  外資總投資市值(百萬)  投信買賣超(千股)  \
# 年月日
# 2015-01-05       3685       514.06     20050364   2797025.78       -752
# 2015-01-06     -37077     -4949.78     20013287   2671773.81      -1212
# 2015-01-07       1525       204.35     20014812   2681984.81      -1341
# 2015-01-08       7797      1075.99     20023409   2763230.44         86
# 2015-01-09     -32026     -4291.48     19991382   2678845.19      -1495
# ...               ...          ...          ...          ...        ...
# 2026-03-02     -19539    -38589.53     18643625  36821159.89       2624
# 2026-03-03     -21195    -41012.33     18619872  36029452.50       1279
# 2026-03-04     -27354    -51015.21     18586949  34664660.15       1467
# 2026-03-05      -9756    -18536.40     18572138  35287062.91       1494
# 2026-03-06     -10927    -20652.03     18558913  35076345.16        911
#
#             投信買賣超市值(百萬)  投信持股數(千股)  投信持股數市值(百萬)  自營買賣超(千股)  自營買賣超市值(百萬)  \
# 年月日
# 2015-01-05      -104.90     244589     34120.17        545        76.03
# 2015-01-06      -161.80     243377     32490.83       3307       441.48
# 2015-01-07      -179.69     242036     32432.82       1386       185.72
# 2015-01-08        11.87     242122     33412.84       -624       -86.11
# 2015-01-09      -200.33     240627     32244.02        -13        -1.74
# ...                 ...        ...          ...        ...          ...
# 2026-03-02      5182.40     717775   1417605.63        514      1015.15
# 2026-03-03      2474.87     719054   1391369.49        897      1735.70
# 2026-03-04      2735.96     720520   1343769.80        799      1490.14
# 2026-03-05      2838.60     722016   1371830.40        118       224.20
# 2026-03-06      1721.79     722925   1366328.25        866      1636.74
#
#             自營自行買賣超(千股)  自營自行買賣超(百萬)  自營避險買賣超(千股)  自營避險買賣超(百萬)  自營持股數(千股)  \
# 年月日
# 2015-01-05         -178     -24831.0          723     100858.5      11338
# 2015-01-06         2451     327208.5          856     114276.0      14645
# 2015-01-07          940     125960.0          446      59764.0      16031
# 2015-01-08         -233     -32154.0         -391     -53958.0      15407
# 2015-01-09        -1376    -184384.0         1363     182642.0      15394
# ...                 ...          ...          ...          ...        ...
# 2026-03-02          104     205400.0          410     809750.0      37702
# 2026-03-03         -132    -255420.0         1029    1991115.0      38599
# 2026-03-04        -1130   -2107450.0         1929    3597585.0      39398
# 2026-03-05         -666   -1265400.0          784    1489600.0      39516
# 2026-03-06          194     366660.0          672    1270080.0      40382
#
#             自營持股數市值(百萬)  合計買賣超(千股)  合計買賣超市值(百萬)  合計持股數(千股)  合計持股數市值(百萬)
# 年月日
# 2015-01-05      1581.65       3478       485.18   20306291   2832727.59
# 2015-01-06      1955.11     -34982     -4670.10   20271309   2706219.75
# 2015-01-07      2148.15       1570       210.38   20272879   2716565.79
# 2015-01-08      2126.17       7259      1001.74   20280938   2798769.44
# 2015-01-09      2062.80     -33534     -4493.56   20247403   2713152.00
# ...                 ...        ...          ...        ...          ...
# 2026-03-02     74461.45     -16401    -32391.98   19399102  38313226.96
# 2026-03-03     74689.07     -19020    -36803.70   19377525  37495511.05
# 2026-03-04     73477.27     -25089    -46790.99   19346867  36081907.22
# 2026-03-05     75080.40      -8144    -15473.60   19333670  36733973.71
# 2026-03-06     76321.98      -9150    -17293.50   19322220  36518995.39
#
# [2720 rows x 20 columns]

# %% [markdown]
# 確認時間序列

# %%
print("Start Date:", majorTraded.index.min())
print("End Date:", majorTraded.index.max())
# Out:
# Start Date: 2015-01-05 00:00:00
# End Date: 2026-03-06 00:00:00

# %% [markdown]
# ## 📊 Step 3 — 缺失值檢查

# %%
print("===== Missing Values =====")

missing_table = majorTraded.isnull().sum().sort_values(ascending=False)

missing_table
# Out:
# ===== Missing Values =====
# 外資買賣超(千股)      0
# 外資買賣超市值(百萬)    0
# 外資總投資股數(千股)    0
# 外資總投資市值(百萬)    0
# 投信買賣超(千股)      0
# 投信買賣超市值(百萬)    0
# 投信持股數(千股)      0
# 投信持股數市值(百萬)    0
# 自營買賣超(千股)      0
# 自營買賣超市值(百萬)    0
# 自營自行買賣超(千股)    0
# 自營自行買賣超(百萬)    0
# 自營避險買賣超(千股)    0
# 自營避險買賣超(百萬)    0
# 自營持股數(千股)      0
# 自營持股數市值(百萬)    0
# 合計買賣超(千股)      0
# 合計買賣超市值(百萬)    0
# 合計持股數(千股)      0
# 合計持股數市值(百萬)    0
# dtype: int64

# %%
# 檢查 majorTraded 是否有遺漏值
missing_count = majorTraded.isnull().sum()
print("各欄位遺漏值數量：")
print(missing_count[missing_count > 0] if any(missing_count > 0) else "完全沒有遺漏值")
# Out:
# 各欄位遺漏值數量：
# 完全沒有遺漏值

# %% [markdown]
# 如果要看比例：

# %%
missing_ratio = (majorTraded.isnull().sum() / len(majorTraded))*100

missing_df = pd.DataFrame({
    "Missing Count": majorTraded.isnull().sum(),
    "Missing Ratio %": missing_ratio
})

missing_df.sort_values("Missing Ratio %", ascending=False)
# Out:
#              Missing Count  Missing Ratio %
# 外資買賣超(千股)                0              0.0
# 外資買賣超市值(百萬)              0              0.0
# 外資總投資股數(千股)              0              0.0
# 外資總投資市值(百萬)              0              0.0
# 投信買賣超(千股)                0              0.0
# 投信買賣超市值(百萬)              0              0.0
# 投信持股數(千股)                0              0.0
# 投信持股數市值(百萬)              0              0.0
# 自營買賣超(千股)                0              0.0
# 自營買賣超市值(百萬)              0              0.0
# 自營自行買賣超(千股)              0              0.0
# 自營自行買賣超(百萬)              0              0.0
# 自營避險買賣超(千股)              0              0.0
# 自營避險買賣超(百萬)              0              0.0
# 自營持股數(千股)                0              0.0
# 自營持股數市值(百萬)              0              0.0
# 合計買賣超(千股)                0              0.0
# 合計買賣超市值(百萬)              0              0.0
# 合計持股數(千股)                0              0.0
# 合計持股數市值(百萬)              0              0.0

# %% [markdown]
# ## 📊 Step 4 — 重複資料檢查

# %%
duplicates = majorTraded.index.duplicated().sum()

print("Duplicate Date Rows:", duplicates)
# Out:
# Duplicate Date Rows: 0

# %% [markdown]
# ## 📊 Step 6 — 基本統計描述

# %%
majorTraded.describe().T
# Out:
#               count          mean           std          min           25%  \
# 外資買賣超(千股)    2720.0 -4.689393e+02  1.266844e+04    -71035.00 -6.125500e+03
# 外資買賣超市值(百萬)  2720.0 -4.001393e+02  7.173323e+03    -51015.21 -2.242805e+03
# 外資總投資股數(千股)  2720.0  1.964821e+07  6.706388e+05  18329100.00  1.905713e+07
# 外資總投資市值(百萬)  2720.0  9.303322e+06  6.639355e+06   2258741.80  4.439024e+06
# 投信買賣超(千股)    2720.0  6.237831e+01  6.256146e+02     -4966.00 -1.745000e+02
# 投信買賣超市值(百萬)  2720.0  6.963585e+01  5.109537e+02     -6321.42 -5.646000e+01
# 投信持股數(千股)    2720.0  2.899229e+05  1.452204e+05    101877.00  1.611750e+05
# 投信持股數市值(百萬)  2720.0  1.817532e+05  2.318338e+05     21597.92  3.554994e+04
# 自營買賣超(千股)    2720.0  5.798309e+01  1.264704e+03    -12026.00 -4.370000e+02
# 自營買賣超市值(百萬)  2720.0  6.020302e+01  7.525395e+02     -7666.71 -1.473625e+02
# 自營自行買賣超(千股)  2720.0  1.046140e+01  8.700908e+02     -8379.00 -2.832500e+02
# 自營自行買賣超(百萬)  2720.0  1.534073e+04  5.169876e+05  -4901715.00 -1.004142e+05
# 自營避險買賣超(千股)  2720.0  4.752904e+01  5.904367e+02     -4635.00 -1.910000e+02
# 自營避險買賣超(百萬)  2720.0  4.486849e+04  3.435392e+05  -3623490.00 -6.733075e+04
# 自營持股數(千股)    2720.0  1.746457e+04  1.294377e+04         0.00  6.045750e+03
# 自營持股數市值(百萬)  2720.0  1.099968e+04  1.416740e+04         0.00  1.342330e+03
# 合計買賣超(千股)    2720.0 -3.485871e+02  1.259882e+04    -71321.00 -5.890500e+03
# 合計買賣超市值(百萬)  2720.0 -2.703106e+02  7.102428e+03    -47465.49 -2.115938e+03
# 合計持股數(千股)    2720.0  1.995559e+07  5.531571e+05  18759139.00  1.955587e+07
# 合計持股數市值(百萬)  2720.0  9.496075e+06  6.873248e+06   2303430.11  4.471840e+06
#
#                       50%           75%          max
# 外資買賣超(千股)   -4.900000e+01  5.750000e+03    112956.00
# 外資買賣超市值(百萬) -2.077500e+01  2.016492e+03     70710.46
# 外資總投資股數(千股)  1.971463e+07  2.020748e+07  20799822.00
# 外資總投資市值(百萬)  7.193600e+06  1.154411e+07  37646633.12
# 投信買賣超(千股)    1.800000e+01  2.752500e+02      5322.00
# 投信買賣超市值(百萬)  5.085000e+00  1.107775e+02      7663.68
# 投信持股數(千股)    2.445970e+05  4.236370e+05    722925.00
# 投信持股數市值(百萬)  8.393127e+04  2.312457e+05   1438607.24
# 自營買賣超(千股)    5.000000e+01  5.562500e+02     11898.00
# 自營買賣超市值(百萬)  1.557500e+01  2.174500e+02      6175.06
# 自營自行買賣超(千股)  8.000000e+00  3.032500e+02     10431.00
# 自營自行買賣超(百萬)  2.298750e+03  1.094900e+05   5413689.00
# 自營避險買賣超(千股)  3.000000e+01  2.992500e+02      4274.00
# 自營避險買賣超(百萬)  9.293000e+03  1.128146e+05   4333665.00
# 自營持股數(千股)    1.548000e+04  2.736200e+04     52029.00
# 自營持股數市值(百萬)  4.425515e+03  1.719688e+04     76321.98
# 合計買賣超(千股)    8.650000e+01  5.674000e+03    115039.00
# 合計買賣超市值(百萬)  2.669000e+01  1.992408e+03     72014.41
# 合計持股數(千股)    2.000360e+07  2.042231e+07  20938885.00
# 合計持股數市值(百萬)  7.327548e+06  1.170110e+07  39157627.21

# %% [markdown]
# ## 📊 Step 7 — 極端值檢查（Outlier Detection）
#
# 金融資料非常重要的一步

# %%
plt.figure(figsize=(14,6))

sns.boxplot(data=majorTraded[['外資買賣超(千股)',
                              '投信買賣超(千股)',
                              '自營買賣超(千股)']])

plt.title("Institutional Net Buy/Sell Distribution")
plt.show()

# %% [markdown]
# ## 📊 Step 8 — 三大法人分布圖

# %%
majorTraded[['外資買賣超(千股)',
              '投信買賣超(千股)',
              '自營買賣超(千股)']].hist(
    figsize=(14,6),
    bins=50
)

plt.suptitle("Distribution of Institutional Trading")
plt.show()

# %% [markdown]
# ## 📊 Step 9 — 相關性分析

# %%
corr = majorTraded.corr()

plt.figure(figsize=(12,10))

sns.heatmap(
    corr,
    cmap="coolwarm",
    center=0
)

plt.title("Correlation Matrix of Institutional Trading")
plt.show()

# %% [markdown]
# ## 📊 Step 10 — 時間序列視覺化

# %%
plt.figure(figsize=(14,6))

plt.plot(majorTraded.index, majorTraded['外資買賣超(千股)'], label='Foreign')
plt.plot(majorTraded.index, majorTraded['投信買賣超(千股)'], label='Trust')
plt.plot(majorTraded.index, majorTraded['自營買賣超(千股)'], label='Dealer')

plt.legend()

plt.title("TSMC Institutional Net Buy/Sell")

plt.show()

# %% [markdown]
# ## 📊 Step 11 — 建立法人合計指標
#
# 這是量化研究常用

# %%
majorTraded['法人買賣超(千股)'] = (
    majorTraded['外資買賣超(千股)'] +
    majorTraded['投信買賣超(千股)'] +
    majorTraded['自營買賣超(千股)']
)

# %%
majorTraded
# Out:
#             外資買賣超(千股)  外資買賣超市值(百萬)  外資總投資股數(千股)  外資總投資市值(百萬)  投信買賣超(千股)  \
# 年月日
# 2015-01-05       3685       514.06     20050364   2797025.78       -752
# 2015-01-06     -37077     -4949.78     20013287   2671773.81      -1212
# 2015-01-07       1525       204.35     20014812   2681984.81      -1341
# 2015-01-08       7797      1075.99     20023409   2763230.44         86
# 2015-01-09     -32026     -4291.48     19991382   2678845.19      -1495
# ...               ...          ...          ...          ...        ...
# 2026-03-02     -19539    -38589.53     18643625  36821159.89       2624
# 2026-03-03     -21195    -41012.33     18619872  36029452.50       1279
# 2026-03-04     -27354    -51015.21     18586949  34664660.15       1467
# 2026-03-05      -9756    -18536.40     18572138  35287062.91       1494
# 2026-03-06     -10927    -20652.03     18558913  35076345.16        911
#
#             投信買賣超市值(百萬)  投信持股數(千股)  投信持股數市值(百萬)  自營買賣超(千股)  自營買賣超市值(百萬)  ...  \
# 年月日                                                                      ...
# 2015-01-05      -104.90     244589     34120.17        545        76.03  ...
# 2015-01-06      -161.80     243377     32490.83       3307       441.48  ...
# 2015-01-07      -179.69     242036     32432.82       1386       185.72  ...
# 2015-01-08        11.87     242122     33412.84       -624       -86.11  ...
# 2015-01-09      -200.33     240627     32244.02        -13        -1.74  ...
# ...                 ...        ...          ...        ...          ...  ...
# 2026-03-02      5182.40     717775   1417605.63        514      1015.15  ...
# 2026-03-03      2474.87     719054   1391369.49        897      1735.70  ...
# 2026-03-04      2735.96     720520   1343769.80        799      1490.14  ...
# 2026-03-05      2838.60     722016   1371830.40        118       224.20  ...
# 2026-03-06      1721.79     722925   1366328.25        866      1636.74  ...
#
#             自營自行買賣超(百萬)  自營避險買賣超(千股)  自營避險買賣超(百萬)  自營持股數(千股)  自營持股數市值(百萬)  \
# 年月日
# 2015-01-05     -24831.0          723     100858.5      11338      1581.65
# 2015-01-06     327208.5          856     114276.0      14645      1955.11
# 2015-01-07     125960.0          446      59764.0      16031      2148.15
# 2015-01-08     -32154.0         -391     -53958.0      15407      2126.17
# 2015-01-09    -184384.0         1363     182642.0      15394      2062.80
# ...                 ...          ...          ...        ...          ...
# 2026-03-02     205400.0          410     809750.0      37702     74461.45
# 2026-03-03    -255420.0         1029    1991115.0      38599     74689.07
# 2026-03-04   -2107450.0         1929    3597585.0      39398     73477.27
# 2026-03-05   -1265400.0          784    1489600.0      39516     75080.40
# 2026-03-06     366660.0          672    1270080.0      40382     76321.98
#
#             合計買賣超(千股)  合計買賣超市值(百萬)  合計持股數(千股)  合計持股數市值(百萬)  法人買賣超(千股)
# 年月日
# 2015-01-05       3478       485.18   20306291   2832727.59       3478
# 2015-01-06     -34982     -4670.10   20271309   2706219.75     -34982
# 2015-01-07       1570       210.38   20272879   2716565.79       1570
# 2015-01-08       7259      1001.74   20280938   2798769.44       7259
# 2015-01-09     -33534     -4493.56   20247403   2713152.00     -33534
# ...               ...          ...        ...          ...        ...
# 2026-03-02     -16401    -32391.98   19399102  38313226.96     -16401
# 2026-03-03     -19020    -36803.70   19377525  37495511.05     -19019
# 2026-03-04     -25089    -46790.99   19346867  36081907.22     -25088
# 2026-03-05      -8144    -15473.60   19333670  36733973.71      -8144
# 2026-03-06      -9150    -17293.50   19322220  36518995.39      -9150
#
# [2720 rows x 21 columns]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/

# %%
# 請顯示 /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/  含有 2330 的檔案名稱
import os

target_dir = "/content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/"
target_str = "2330"

# 檢查資料夾是否存在
if os.path.exists(target_dir):
    # 篩選包含 2330 的檔案名稱
    matched_files = [f for f in os.listdir(target_dir) if target_str in f]

    if matched_files:
        print(f"在 {target_dir} 中找到以下含有 '{target_str}' 的檔案：")
        for file_name in sorted(matched_files):
            print(file_name)
    else:
        print(f"在 {target_dir} 中找不到檔名含有 '{target_str}' 的檔案。")
else:
    print(f"找不到路徑：{target_dir}")
# Out:
# 在 /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/ 中找到以下含有 '2330' 的檔案：
# s2330d20260306.xlsx
# 三大法人買賣超S2330台積電20260209.xlsx
# 三大法人買賣超S2330台積電20260226.xlsx
# 三大法人買賣超S2330台積電20260306.xlsx
# 借券成交S2330台積電20260226.xlsx
# 借券成交S2330台積電20260306.xlsx
# 借券餘額S2330台積電20260306.xlsx
# 借劵餘額S2330台積電20260226.xlsx
# 當日沖銷S2330台積電20260226.xlsx
# 當日沖銷S2330台積電20260306.xlsx
# 融資融券S2330台積電20260306.xlsx
# 融資融劵S2330台積電20260226.xlsx

# %%
# 刪除 三大法人買賣超S2330台積電20260209.xlsx
, 三大法人買賣超S2330台積電20260226.xlsx 二個檔案
import os

target_dir = "/content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/"
files_to_delete = [
    "三大法人買賣超S2330台積電20260209.xlsx",
    "三大法人買賣超S2330台積電20260226.xlsx"
]

for file_name in files_to_delete:
    file_path = os.path.join(target_dir, file_name)
    if os.path.exists(file_path):
        os.remove(file_path)
        print(f"已成功刪除：{file_name}")
    else:
        print(f"找不到檔案，無法刪除：{file_name}")
# Out:
# 已成功刪除：三大法人買賣超S2330台積電20260209.xlsx
# 已成功刪除：三大法人買賣超S2330台積電20260226.xlsx

# %%
# 刪除 包含 20260226 名稱的檔案
import os

target_dir = "/content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/"
pattern = "20260226"

if os.path.exists(target_dir):
    # 找出包含特定字串的檔案
    files_to_remove = [f for f in os.listdir(target_dir) if pattern in f]

    if files_to_remove:
        print(f"開始刪除包含 '{pattern}' 的檔案：")
        for file_name in files_to_remove:
            file_path = os.path.join(target_dir, file_name)
            try:
                os.remove(file_path)
                print(f"已刪除: {file_name}")
            except Exception as e:
                print(f"刪除 {file_name} 時出錯: {e}")
    else:
        print(f"在 {target_dir} 中找不到檔名包含 '{pattern}' 的檔案。")
else:
    print(f"找不到路徑：{target_dir}")
# Out:
# 開始刪除包含 '20260226' 的檔案：
# 已刪除: 當日沖銷S2603長榮20260226.xlsx
# 已刪除: 三大法人買賣超S2603長榮20260226.xlsx
# 已刪除: 融資融劵S2603長榮20260226.xlsx
# 已刪除: 借券成交S2603長榮20260226.xlsx
# 已刪除: 借劵餘額S2603長榮20260226.xlsx
# 已刪除: 借券成交S3443創意20260226.xlsx
# 已刪除: 三大法人買賣超S3443創意20260226.xlsx
# 已刪除: 借劵餘額S3443創意20260226.xlsx
# 已刪除: 融資融劵S3443創意-KY20260226.xlsx
# 已刪除: 當日沖銷S3443創意20260226.xlsx
# 已刪除: 三大法人買賣超S3661世芯-KY20260226.xlsx
# 已刪除: 融資融劵S3661世芯-KY20260226.xlsx
# 已刪除: 當日沖銷S3661世芯-KY20260226.xlsx
# 已刪除: 借劵餘額S3661世芯-KY20260226.xlsx
# 已刪除: 借券成交S3661世芯-KY20260226.xlsx
# 已刪除: 當日沖銷S2330台積電20260226.xlsx
# 已刪除: 融資融劵S2330台積電20260226.xlsx
# 已刪除: 借劵餘額Y9999加權指數20260226.xlsx
# 已刪除: 當日沖銷Y9999加權指數20260226.xlsx
# 已刪除: 三大法人買賣超Y9999加權指數20260226.xlsx
# 已刪除: 融資融劵Y9999加權指數20260226.xlsx
# 已刪除: 借劵餘額S2330台積電20260226.xlsx
# 已刪除: 借券成交S2330台積電20260226.xlsx

# %%
# 請顯示 /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/  含有 2330 的檔案名稱
import os

target_dir = "/content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/"
target_str = "2330"

# 檢查資料夾是否存在
if os.path.exists(target_dir):
    # 篩選包含 2330 的檔案名稱
    matched_files = [f for f in os.listdir(target_dir) if target_str in f]

    if matched_files:
        print(f"在 {target_dir} 中找到以下含有 '{target_str}' 的檔案：")
        for file_name in sorted(matched_files):
            print(file_name)
    else:
        print(f"在 {target_dir} 中找不到檔名含有 '{target_str}' 的檔案。")
else:
    print(f"找不到路徑：{target_dir}")
# Out:
# 在 /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/ 中找到以下含有 '2330' 的檔案：
# s2330d20260306.xlsx
# 三大法人買賣超S2330台積電20260306.xlsx
# 借券成交S2330台積電20260306.xlsx
# 借券餘額S2330台積電20260306.xlsx
# 當日沖銷S2330台積電20260306.xlsx
# 融資融券S2330台積電20260306.xlsx

# %% [markdown]
# # 合併
# 我在 /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/ 中有以下6個檔案：
# s2330d20260306.xlsx
# 三大法人買賣超S2330台積電20260306.xlsx
# 借券成交S2330台積電20260306.xlsx
# 借券餘額S2330台積電20260306.xlsx
# 當日沖銷S2330台積電20260306.xlsx
# 融資融券S2330台積電20260306.xlsx , 想以欄位 "年月日" 為主 將所有檔案合併 成 s2330df 變數做日後量化交易分析用, 但是有些檔案的欄位是(年月日,年月,日期) 其中一項 . 請給我 colab 程式碼

# %%
# =========================================================
# S2330 台積電多資料來源整併
# =========================================================

from google.colab import drive
drive.mount('/content/drive')

import os
import pandas as pd
import numpy as np
from functools import reduce

# -------------------------------------------------
# 工作路徑
# -------------------------------------------------

BASE_PATH = "/content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026"
os.chdir(BASE_PATH)

print("Current Path:", os.getcwd())


# -------------------------------------------------
# Excel 檔案列表
# -------------------------------------------------

file_list = [
    "s2330d20260306.xlsx",
    "三大法人買賣超S2330台積電20260306.xlsx",
    "借券成交S2330台積電20260306.xlsx",
    "借券餘額S2330台積電20260306.xlsx",
    "當日沖銷S2330台積電20260306.xlsx",
    "融資融券S2330台積電20260306.xlsx"
]


# -------------------------------------------------
# 清理欄位名稱
# -------------------------------------------------

def clean_columns(df):

    df.columns = (
        df.columns
        .astype(str)
        .str.strip()
        .str.replace("\n","")
        .str.replace(" ","")
    )

    return df


# -------------------------------------------------
# 標準化日期欄位
# -------------------------------------------------

def standardize_date_column(df):

    candidates = ['年月日','日期','年月']

    for col in candidates:

        if col in df.columns:

            df = df.rename(columns={col:'年月日'})

            df['年月日'] = pd.to_datetime(df['年月日'], errors='coerce')

            return df

    raise ValueError("找不到日期欄位")


# -------------------------------------------------
# 讀取 Excel
# -------------------------------------------------

def read_excel_file(file):

    print("Reading:", file)

    # ⭐ 關鍵：skip 前兩列
    df = pd.read_excel(file, skiprows=2)

    df = clean_columns(df)

    df = standardize_date_column(df)

    df = df.sort_values("年月日")

    return df


# -------------------------------------------------
# 加入欄位前綴
# -------------------------------------------------

def add_prefix(df, file):

    prefix = file.replace(".xlsx","")

    rename_dict = {}

    for col in df.columns:

        if col != "年月日":

            rename_dict[col] = prefix + "_" + col

    df = df.rename(columns=rename_dict)

    return df


# -------------------------------------------------
# 讀取所有資料
# -------------------------------------------------

dfs = []

for file in file_list:

    df = read_excel_file(file)

    df = add_prefix(df, file)

    dfs.append(df)


print("Loaded files:", len(dfs))


# -------------------------------------------------
# 合併資料
# -------------------------------------------------

s2330df = reduce(

    lambda left,right:

    pd.merge(left, right, on='年月日', how='outer'),

    dfs

)


# -------------------------------------------------
# 排序
# -------------------------------------------------

s2330df = s2330df.sort_values("年月日")


# -------------------------------------------------
# 設定 index
# -------------------------------------------------

s2330df = s2330df.set_index("年月日")


# -------------------------------------------------
# 檢查結果
# -------------------------------------------------

print("Merged shape:", s2330df.shape)

print("\nColumns:")

print(s2330df.columns)


print("\nPreview")

display(s2330df.head())


# -------------------------------------------------
# 缺失值檢查
# -------------------------------------------------

missing = s2330df.isnull().sum().sort_values(ascending=False)

print("\nMissing Values")

display(missing.head(20))


# -------------------------------------------------
# 存檔
# -------------------------------------------------

save_path = BASE_PATH + "/s2330df_merged.csv"

s2330df.to_csv(save_path)

print("Saved:", save_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Current Path: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026
# Reading: s2330d20260306.xlsx
# Reading: 三大法人買賣超S2330台積電20260306.xlsx
# Reading: 借券成交S2330台積電20260306.xlsx
# Reading: 借券餘額S2330台積電20260306.xlsx
# Reading: 當日沖銷S2330台積電20260306.xlsx
# Reading: 融資融券S2330台積電20260306.xlsx
# Loaded files: 6
# Merged shape: (17295, 94)
#
# Columns:
# Index(['s2330d20260306_開盤價(元)', 's2330d20260306_最高價(元)',
#        's2330d20260306_最低價(元)', 's2330d20260306_收盤價(元)',
#        's2330d20260306_成交量(千股)', 's2330d20260306_成交值(千元)',
#        's2330d20260306_報酬率％', 's2330d20260306_週轉率％',
#        's2330d20260306_流通在外股數(千股)', 's2330d20260306_市值(百萬元)',
#        's2330d20260306_最後揭示買價', 's2330d20260306_最後揭示賣價',
#        's2330d20260306_報酬率-Ln', 's2330d20260306_市值比重％',
#        's2330d20260306_成交值比重％', 's2330d20260306_成交筆數(筆)',
#        's2330d20260306_本益比-TSE', 's2330d20260306_本益比-TEJ',
#        's2330d20260306_股價淨值比-TSE', 's2330d20260306_股價淨值比-TEJ',
#        '三大法人買賣超S2330台積電20260306_外資買賣超(千股)',
#        '三大法人買賣超S2330台積電20260306_外資買賣超市值(百萬)',
#        '三大法人買賣超S2330台積電20260306_外資總投資股數(千股)',
#        '三大法人買賣超S2330台積電20260306_外資總投資市值(百萬)',
#        '三大法人買賣超S2330台積電20260306_投信買賣超(千股)',
#        '三大法人買賣超S2330台積電20260306_投信買賣超市值(百萬)',
#        '三大法人買賣超S2330台積電20260306_投信持股數(千股)',
#        '三大法人買賣超S2330台積電20260306_投信持股數市值(百萬)',
#        '三大法人買賣超S2330台積電20260306_自營買賣超(千股)',
#        '三大法人買賣超S2330台積電20260306_自營買賣超市值(百萬)',
#        '三大法人買賣超S2330台積電20260306_自營自行買賣超(千股)',
#        '三大法人買賣超S2330台積電20260306_自營自行買賣超(百萬)',
#        '三大法人買賣超S2330台積電20260306_自營避險買賣超(千股)',
#        '三大法人買賣超S2330台積電20260306_自營避險買賣超(百萬)',
#        '三大法人買賣超S2330台積電20260306_自營持股數(千股)',
#        '三大法人買賣超S2330台積電20260306_自營持股數市值(百萬)',
#        '三大法人買賣超S2330台積電20260306_合計買賣超(千股)',
#        '三大法人買賣超S2330台積電20260306_合計買賣超市值(百萬)',
#        '三大法人買賣超S2330台積電20260306_合計持股數(千股)',
#        '三大法人買賣超S2330台積電20260306_合計持股數市值(百萬)', '借券成交S2330台積電20260306_序號',
#        '借券成交S2330台積電20260306_交易方式', '借券成交S2330台積電20260306_成交張數',
#        '借券成交S2330台積電20260306_成交費率%', '借券成交S2330台積電20260306_收盤價',
#        '借券成交S2330台積電20260306_還券日期', '借券成交S2330台積電20260306_借券天數',
#        '借券餘額S2330台積電20260306_收盤價(元)', '借券餘額S2330台積電20260306_合計-借券(千股)',
#        '借券餘額S2330台積電20260306_合計-還券(千股)', '借券餘額S2330台積電20260306_合計-借券餘額(千股)',
#        '借券餘額S2330台積電20260306_合計-借券餘額市值(元)', '借券餘額S2330台積電20260306_証交所-借券(千股)',
#        '借券餘額S2330台積電20260306_証交所-還券(千股)', '借券餘額S2330台積電20260306_証交所-借券餘額(千股)',
#        '借券餘額S2330台積電20260306_証交所-借券餘額市值(元)',
#        '借券餘額S2330台積電20260306_證商/證金-借券(千股)',
#        '借券餘額S2330台積電20260306_證商/證金-還券(千股)',
#        '借券餘額S2330台積電20260306_證商/證金-借券餘額(千股)',
#        '借券餘額S2330台積電20260306_證商/證金借券餘額市值(元)', '借券餘額S2330台積電20260306_市場別',
#        '當日沖銷S2330台積電20260306_收盤價(元)', '當日沖銷S2330台積電20260306_成交量(千股)',
#        '當日沖銷S2330台積電20260306_成交值(千元)', '當日沖銷S2330台積電20260306_當日沖銷交易總成交股數(千股)',
#        '當日沖銷S2330台積電20260306_當日沖銷交易總成交股數占市場比重%',
#        '當日沖銷S2330台積電20260306_當日沖銷交易總買進成交金額(千元)',
#        '當日沖銷S2330台積電20260306_當日沖銷交易總買進成交金額占市場比重%',
#        '當日沖銷S2330台積電20260306_當日沖銷交易總賣出成交金額(千元)',
#        '當日沖銷S2330台積電20260306_當日沖銷交易總賣出成交金額占市場比重%', '當日沖銷S2330台積電20260306_報酬率％',
#        '當日沖銷S2330台積電20260306_週轉率％', '當日沖銷S2330台積電20260306_當沖比重(資券互抵)',
#        '當日沖銷S2330台積電20260306_現沖+當沖比重', '融資融券S2330台積電20260306_融資餘額(張)',
#        '融資融券S2330台積電20260306_融資餘額(千元)', '融資融券S2330台積電20260306_融資買進(張)',
#        '融資融券S2330台積電20260306_融資買進(千元)', '融資融券S2330台積電20260306_融資賣出(張)',
#        '融資融券S2330台積電20260306_融資賣出(千元)', '融資融券S2330台積電20260306_融資現金償還(張)',
#        '融資融券S2330台積電20260306_融資現金償還(千元)', '融資融券S2330台積電20260306_融資增減(張)',
#        '融資融券S2330台積電20260306_融資增減(千元)', '融資融券S2330台積電20260306_融資增減比率',
#        '融資融券S2330台積電20260306_融資使用率', '融資融券S2330台積電20260306_融資限額',
#        '融資融券S2330台積電20260306_融券餘額(張)', '融資融券S2330台積電20260306_融券餘額(千元)',
#        '融資融券S2330台積電20260306_融券買進(張)', '融資融券S2330台積電20260306_融券買進(千元)',
#        '融資融券S2330台積電20260306_融券賣出(張)', '融資融券S2330台積電20260306_融券賣出(千元)',
#        '融資融券S2330台積電20260306_融券現券償還(張)'],
#       dtype='object')
#
# Preview
#             s2330d20260306_開盤價(元)  s2330d20260306_最高價(元)  \
# 年月日
# 2015-01-05               103.3608               103.3608
# 2015-01-05               103.3608               103.3608
# 2015-01-05               103.3608               103.3608
# 2015-01-05               103.3608               103.3608
# 2015-01-06               101.1538               101.1538
#
#             s2330d20260306_最低價(元)  s2330d20260306_收盤價(元)  \
# 年月日
# 2015-01-05               101.1538               102.6251
# 2015-01-05               101.1538               102.6251
# 2015-01-05               101.1538               102.6251
# 2015-01-05               101.1538               102.6251
# 2015-01-06                97.8433                98.2111
#
#             s2330d20260306_成交量(千股)  s2330d20260306_成交值(千元)  \
# 年月日
# 2015-01-05                 32214.0               4459516.0
# 2015-01-05                 32214.0               4459516.0
# 2015-01-05                 32214.0               4459516.0
# 2015-01-05                 32214.0               4459516.0
# 2015-01-06                 67649.0               9104346.0
#
#             s2330d20260306_報酬率％  s2330d20260306_週轉率％  \
# 年月日
# 2015-01-05              -1.0638               0.1242
# 2015-01-05              -1.0638               0.1242
# 2015-01-05              -1.0638               0.1242
# 2015-01-05              -1.0638               0.1242
# 2015-01-06              -4.3011               0.2609
#
#             s2330d20260306_流通在外股數(千股)  s2330d20260306_市值(百萬元)  ...  \
# 年月日                                                            ...
# 2015-01-05                 25929662.0               3617187.0  ...
# 2015-01-05                 25929662.0               3617187.0  ...
# 2015-01-05                 25929662.0               3617187.0  ...
# 2015-01-05                 25929662.0               3617187.0  ...
# 2015-01-06                 25929662.0               3461609.0  ...
#
#            融資融券S2330台積電20260306_融資增減比率 融資融券S2330台積電20260306_融資使用率  \
# 年月日
# 2015-01-05                        2.22                       0.32
# 2015-01-05                        2.22                       0.32
# 2015-01-05                        2.22                       0.32
# 2015-01-05                        2.22                       0.32
# 2015-01-06                       13.26                       0.36
#
#             融資融券S2330台積電20260306_融資限額  融資融券S2330台積電20260306_融券餘額(張)  \
# 年月日
# 2015-01-05                  6482398.0                        4830.0
# 2015-01-05                  6482398.0                        4830.0
# 2015-01-05                  6482398.0                        4830.0
# 2015-01-05                  6482398.0                        4830.0
# 2015-01-06                  6482398.0                        3493.0
#
#             融資融券S2330台積電20260306_融券餘額(千元)  融資融券S2330台積電20260306_融券買進(張)  \
# 年月日
# 2015-01-05                      668616.90                         457.0
# 2015-01-05                      668616.90                         457.0
# 2015-01-05                      668616.90                         457.0
# 2015-01-05                      668616.90                         457.0
# 2015-01-06                      470087.94                        1432.0
#
#             融資融券S2330台積電20260306_融券買進(千元)  融資融券S2330台積電20260306_融券賣出(張)  \
# 年月日
# 2015-01-05                       63262.51                         231.0
# 2015-01-05                       63262.51                         231.0
# 2015-01-05                       63262.51                         231.0
# 2015-01-05                       63262.51                         231.0
# 2015-01-06                      192718.56                          95.0
#
#             融資融券S2330台積電20260306_融券賣出(千元)  融資融券S2330台積電20260306_融券現券償還(張)
# 年月日
# 2015-01-05                       31977.33                             0.0
# 2015-01-05                       31977.33                             0.0
# 2015-01-05                       31977.33                             0.0
# 2015-01-05                       31977.33                             0.0
# 2015-01-06                       12785.10                             0.0
#
# [5 rows x 94 columns]
# Missing Values
# 借券成交S2330台積電20260306_交易方式          105
# 借券成交S2330台積電20260306_序號            105
# 借券成交S2330台積電20260306_收盤價           105
# 借券成交S2330台積電20260306_還券日期          105
# 借券成交S2330台積電20260306_成交費率%         105
# 借券成交S2330台積電20260306_成交張數          105
# 借券成交S2330台積電20260306_借券天數          105
# 融資融券S2330台積電20260306_融資餘額(張)        43
# 融資融券S2330台積電20260306_融券賣出(千元)       43
# 融資融券S2330台積電20260306_融券現券償還(張)      43
# 融資融券S2330台積電20260306_融券買進(張)        43
# 融資融券S2330台積電20260306_融資餘額(千元)       43
# 融資融券S2330台積電20260306_融資買進(張)        43
# 融資融券S2330台積電20260306_融資買進(千元)       43
# 融資融券S2330台積電20260306_融券買進(千元)       43
# 融資融券S2330台積電20260306_融券賣出(張)        43
# 融資融券S2330台積電20260306_融資增減(千元)       43
# 融資融券S2330台積電20260306_融資增減(張)        43
# 融資融券S2330台積電20260306_融資現金償還(千元)     43
# 融資融券S2330台積電20260306_融券餘額(千元)       43
# dtype: int64
# Saved: /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/s2330df_merged.csv

# %%
s2330df
# Out:
#             s2330d20260306_開盤價(元)  s2330d20260306_最高價(元)  \
# 年月日
# 2015-01-05               103.3608               103.3608
# 2015-01-05               103.3608               103.3608
# 2015-01-05               103.3608               103.3608
# 2015-01-05               103.3608               103.3608
# 2015-01-06               101.1538               101.1538
# ...                           ...                    ...
# 2026-03-05              1940.0000              1960.0000
# 2026-03-06              1880.0000              1900.0000
# 2026-03-06              1880.0000              1900.0000
# 2026-03-06              1880.0000              1900.0000
# 2026-03-06              1880.0000              1900.0000
#
#             s2330d20260306_最低價(元)  s2330d20260306_收盤價(元)  \
# 年月日
# 2015-01-05               101.1538               102.6251
# 2015-01-05               101.1538               102.6251
# 2015-01-05               101.1538               102.6251
# 2015-01-05               101.1538               102.6251
# 2015-01-06                97.8433                98.2111
# ...                           ...                    ...
# 2026-03-05              1895.0000              1900.0000
# 2026-03-06              1880.0000              1890.0000
# 2026-03-06              1880.0000              1890.0000
# 2026-03-06              1880.0000              1890.0000
# 2026-03-06              1880.0000              1890.0000
#
#             s2330d20260306_成交量(千股)  s2330d20260306_成交值(千元)  \
# 年月日
# 2015-01-05                 32214.0               4459516.0
# 2015-01-05                 32214.0               4459516.0
# 2015-01-05                 32214.0               4459516.0
# 2015-01-05                 32214.0               4459516.0
# 2015-01-06                 67649.0               9104346.0
# ...                            ...                     ...
# 2026-03-05                 56489.0             108468004.0
# 2026-03-06                 34307.0              64781776.0
# 2026-03-06                 34307.0              64781776.0
# 2026-03-06                 34307.0              64781776.0
# 2026-03-06                 34307.0              64781776.0
#
#             s2330d20260306_報酬率％  s2330d20260306_週轉率％  \
# 年月日
# 2015-01-05              -1.0638               0.1242
# 2015-01-05              -1.0638               0.1242
# 2015-01-05              -1.0638               0.1242
# 2015-01-05              -1.0638               0.1242
# 2015-01-06              -4.3011               0.2609
# ...                         ...                  ...
# 2026-03-05               1.8767               0.2178
# 2026-03-06              -0.5263               0.1323
# 2026-03-06              -0.5263               0.1323
# 2026-03-06              -0.5263               0.1323
# 2026-03-06              -0.5263               0.1323
#
#             s2330d20260306_流通在外股數(千股)  s2330d20260306_市值(百萬元)  ...  \
# 年月日                                                            ...
# 2015-01-05                 25929662.0               3617187.0  ...
# 2015-01-05                 25929662.0               3617187.0  ...
# 2015-01-05                 25929662.0               3617187.0  ...
# 2015-01-05                 25929662.0               3617187.0  ...
# 2015-01-06                 25929662.0               3461609.0  ...
# ...                               ...                     ...  ...
# 2026-03-05                 25932525.0              49271797.0  ...
# 2026-03-06                 25932525.0              49012471.0  ...
# 2026-03-06                 25932525.0              49012471.0  ...
# 2026-03-06                 25932525.0              49012471.0  ...
# 2026-03-06                 25932525.0              49012471.0  ...
#
#            融資融券S2330台積電20260306_融資增減比率 融資融券S2330台積電20260306_融資使用率  \
# 年月日
# 2015-01-05                        2.22                       0.32
# 2015-01-05                        2.22                       0.32
# 2015-01-05                        2.22                       0.32
# 2015-01-05                        2.22                       0.32
# 2015-01-06                       13.26                       0.36
# ...                                ...                        ...
# 2026-03-05                        3.35                       0.35
# 2026-03-06                        2.96                       0.36
# 2026-03-06                        2.96                       0.36
# 2026-03-06                        2.96                       0.36
# 2026-03-06                        2.96                       0.36
#
#             融資融券S2330台積電20260306_融資限額  融資融券S2330台積電20260306_融券餘額(張)  \
# 年月日
# 2015-01-05                  6482398.0                        4830.0
# 2015-01-05                  6482398.0                        4830.0
# 2015-01-05                  6482398.0                        4830.0
# 2015-01-05                  6482398.0                        4830.0
# 2015-01-06                  6482398.0                        3493.0
# ...                               ...                           ...
# 2026-03-05                  6483131.0                         165.0
# 2026-03-06                  6483131.0                         155.0
# 2026-03-06                  6483131.0                         155.0
# 2026-03-06                  6483131.0                         155.0
# 2026-03-06                  6483131.0                         155.0
#
#             融資融券S2330台積電20260306_融券餘額(千元)  融資融券S2330台積電20260306_融券買進(張)  \
# 年月日
# 2015-01-05                      668616.90                         457.0
# 2015-01-05                      668616.90                         457.0
# 2015-01-05                      668616.90                         457.0
# 2015-01-05                      668616.90                         457.0
# 2015-01-06                      470087.94                        1432.0
# ...                                   ...                           ...
# 2026-03-05                      316821.53                           9.0
# 2026-03-06                      292682.59                           7.0
# 2026-03-06                      292682.59                           7.0
# 2026-03-06                      292682.59                           7.0
# 2026-03-06                      292682.59                           7.0
#
#             融資融券S2330台積電20260306_融券買進(千元)  融資融券S2330台積電20260306_融券賣出(張)  \
# 年月日
# 2015-01-05                       63262.51                         231.0
# 2015-01-05                       63262.51                         231.0
# 2015-01-05                       63262.51                         231.0
# 2015-01-05                       63262.51                         231.0
# 2015-01-06                      192718.56                          95.0
# ...                                   ...                           ...
# 2026-03-05                       17281.17                           5.0
# 2026-03-06                       13217.92                           0.0
# 2026-03-06                       13217.92                           0.0
# 2026-03-06                       13217.92                           0.0
# 2026-03-06                       13217.92                           0.0
#
#             融資融券S2330台積電20260306_融券賣出(千元)  融資融券S2330台積電20260306_融券現券償還(張)
# 年月日
# 2015-01-05                       31977.33                             0.0
# 2015-01-05                       31977.33                             0.0
# 2015-01-05                       31977.33                             0.0
# 2015-01-05                       31977.33                             0.0
# 2015-01-06                       12785.10                             0.0
# ...                                   ...                             ...
# 2026-03-05                        9600.65                             0.0
# 2026-03-06                           0.00                             3.0
# 2026-03-06                           0.00                             3.0
# 2026-03-06                           0.00                             3.0
# 2026-03-06                           0.00                             3.0
#
# [17295 rows x 94 columns]

# %% [markdown]
# 我在 /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/ 中有以下5個檔案： s2330d20260306.xlsx 三大法人買賣超S2330台積電20260306.xlsx 借券餘額S2330台積電20260306.xlsx 當日沖銷S2330台積電20260306.xlsx 融資融券S2330台積電20260306.xlsx , 想以欄位 "年月日" 為主 將所有檔案合併 成 s2330df 變數做日後量化交易分析用, 但是有些檔案的欄位是(年月日,年月,日期) 其中一項 . 請給我 colab 程式碼(資料的 前二列不是資料)

# %%
# =========================================================
# S2330 台積電多來源資料整併程式
# Google Colab 專用
# 目的：
# 1. 讀取 5 個 Excel 檔
# 2. 跳過前兩列非資料列
# 3. 自動辨識日期欄位（年月日 / 年月 / 日期）
# 4. 統一為 年月日
# 5. 以 年月日 合併成 s2330df
# =========================================================

# -----------------------------
# 1. 掛載 Google Drive
# -----------------------------
from google.colab import drive
drive.mount('/content/drive')

# -----------------------------
# 2. 載入套件
# -----------------------------
import os
import re
import warnings
from functools import reduce

import pandas as pd
import numpy as np

warnings.filterwarnings("ignore")

# -----------------------------
# 3. 設定路徑
# -----------------------------
BASE_PATH = "/content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026"
os.chdir(BASE_PATH)

print("目前工作路徑：", os.getcwd())

# -----------------------------
# 4. 指定檔案清單（5個）
# -----------------------------
file_list = [
    "s2330d20260306.xlsx",
    "三大法人買賣超S2330台積電20260306.xlsx",
    "借券餘額S2330台積電20260306.xlsx",
    "當日沖銷S2330台積電20260306.xlsx",
    "融資融券S2330台積電20260306.xlsx"
]

print("\n=== 檢查檔案是否存在 ===")
for f in file_list:
    full_path = os.path.join(BASE_PATH, f)
    print(f"{f} -> {'存在' if os.path.exists(full_path) else '不存在'}")

# -----------------------------
# 5. 清理欄位名稱
# -----------------------------
def clean_column_names(df):
    """
    清理欄位名稱：
    - 去前後空白
    - 去除換行
    - 去除多餘空白
    """
    df.columns = [
        str(col).strip().replace("\n", "").replace("\r", "").replace(" ", "")
        for col in df.columns
    ]
    return df

# -----------------------------
# 6. 日期欄位標準化
# -----------------------------
def standardize_date_column(df, file_name=""):
    """
    自動辨識日期欄位：
    候選欄位：年月日 / 日期 / 年月
    並統一命名為：年月日
    """

    df = clean_column_names(df)

    date_candidates = ["年月日", "日期", "年月"]
    found_col = None

    for col in date_candidates:
        if col in df.columns:
            found_col = col
            break

    if found_col is None:
        raise ValueError(f"[{file_name}] 找不到日期欄位，欄位如下：{list(df.columns)}")

    # 統一名稱為 年月日
    if found_col != "年月日":
        df = df.rename(columns={found_col: "年月日"})

    # 先轉成字串
    df["年月日"] = df["年月日"].astype(str).str.strip()

    # 處理「年月」可能是 202401 這種格式，補成 20240101
    mask_yyyymm = df["年月日"].str.match(r"^\d{6}$", na=False)
    df.loc[mask_yyyymm, "年月日"] = df.loc[mask_yyyymm, "年月日"] + "01"

    # 如果是 8 碼數字，按 YYYYMMDD 解析
    mask_yyyymmdd = df["年月日"].str.match(r"^\d{8}$", na=False)

    converted = pd.Series(pd.NaT, index=df.index, dtype="datetime64[ns]")

    if mask_yyyymmdd.any():
        converted.loc[mask_yyyymmdd] = pd.to_datetime(
            df.loc[mask_yyyymmdd, "年月日"],
            format="%Y%m%d",
            errors="coerce"
        )

    other_mask = ~mask_yyyymmdd
    if other_mask.any():
        converted.loc[other_mask] = pd.to_datetime(
            df.loc[other_mask, "年月日"],
            errors="coerce"
        )

    df["年月日"] = converted

    before_rows = len(df)
    df = df.dropna(subset=["年月日"]).copy()
    after_rows = len(df)

    print(f"[{file_name}] 日期欄位：{found_col} -> 年月日，刪除無效日期 {before_rows - after_rows} 筆")

    return df

# -----------------------------
# 7. 建立檔名前綴
# -----------------------------
def get_file_prefix(file_name):
    """
    根據檔名建立前綴，避免 merge 後欄位同名衝突
    """
    if "三大法人買賣超" in file_name:
        return "major"
    elif "借券餘額" in file_name:
        return "borrow_balance"
    elif "當日沖銷" in file_name:
        return "day_trade"
    elif "融資融券" in file_name:
        return "margin"
    elif "s2330d" in file_name.lower():
        return "price"
    else:
        base = os.path.splitext(file_name)[0]
        base = re.sub(r"[^A-Za-z0-9\u4e00-\u9fff]+", "_", base)
        return base[:30]

# -----------------------------
# 8. 除日期外加前綴
# -----------------------------
def add_prefix_except_date(df, prefix):
    rename_dict = {}
    for col in df.columns:
        if col != "年月日":
            rename_dict[col] = f"{prefix}_{col}"
    df = df.rename(columns=rename_dict)
    return df

# -----------------------------
# 9. 讀取並整理單一 Excel
# -----------------------------
def load_and_prepare_excel(file_name):
    file_path = os.path.join(BASE_PATH, file_name)
    print(f"\n========== 讀取檔案：{file_name} ==========")

    # 重點：前兩列不是資料
    df = pd.read_excel(file_path, skiprows=2)

    print("原始 shape:", df.shape)

    # 清理欄位名稱
    df = clean_column_names(df)

    # 標準化日期欄位
    df = standardize_date_column(df, file_name=file_name)

    # 刪除完全重複列
    before_dup = len(df)
    df = df.drop_duplicates()
    after_dup = len(df)
    print(f"[{file_name}] 刪除完全重複列：{before_dup - after_dup} 筆")

    # 日期排序
    df = df.sort_values("年月日").copy()

    # 若同一日期重複，保留最後一筆
    dup_date_count = df.duplicated(subset=["年月日"]).sum()
    if dup_date_count > 0:
        print(f"[{file_name}] 發現重複日期 {dup_date_count} 筆，保留最後一筆")
        df = df.drop_duplicates(subset=["年月日"], keep="last")

    # 欄位加前綴
    prefix = get_file_prefix(file_name)
    df = add_prefix_except_date(df, prefix)

    print(f"[{file_name}] 整理後 shape:", df.shape)
    print(f"[{file_name}] 日期範圍: {df['年月日'].min()} ~ {df['年月日'].max()}")

    return df

# -----------------------------
# 10. 逐一讀取 5 個檔案
# -----------------------------
df_list = []

for file_name in file_list:
    df_temp = load_and_prepare_excel(file_name)
    df_list.append(df_temp)

print("\n成功載入資料表數量：", len(df_list))

# -----------------------------
# 11. 以 年月日 做 outer merge
# -----------------------------
print("\n========== 開始合併 ==========")

s2330df = reduce(
    lambda left, right: pd.merge(left, right, on="年月日", how="outer"),
    df_list
)

# -----------------------------
# 12. 合併後整理
# -----------------------------
s2330df = s2330df.sort_values("年月日").reset_index(drop=True)

print("合併後 shape:", s2330df.shape)

# -----------------------------
# 13. 缺失值檢查
# -----------------------------
missing_df = pd.DataFrame({
    "欄位名稱": s2330df.columns,
    "缺失值筆數": s2330df.isnull().sum().values,
    "缺失比例(%)": (s2330df.isnull().sum().values / len(s2330df) * 100).round(2)
}).sort_values("缺失值筆數", ascending=False)

print("\n========== 缺失值檢查（前20欄）==========")
display(missing_df.head(20))

# -----------------------------
# 14. 數值欄位嘗試轉型
# -----------------------------
for col in s2330df.columns:
    if col != "年月日":
        s2330df[col] = pd.to_numeric(s2330df[col], errors="ignore")

print("\n========== 資料型態 ==========")
print(s2330df.dtypes)

# -----------------------------
# 15. 設定 年月日 為 index
# -----------------------------
s2330df["年月日"] = pd.to_datetime(s2330df["年月日"])
s2330df = s2330df.sort_values("年月日").set_index("年月日")

print("\n========== 最終 s2330df ==========")
print("shape:", s2330df.shape)
display(s2330df.head())

# -----------------------------
# 16. 存檔
# -----------------------------
csv_path = os.path.join(BASE_PATH, "s2330df_merged.csv")
xlsx_path = os.path.join(BASE_PATH, "s2330df_merged.xlsx")

s2330df.to_csv(csv_path, encoding="utf-8-sig")
s2330df.to_excel(xlsx_path)

print("\n已存檔：")
print(csv_path)
print(xlsx_path)

# -----------------------------
# 17. 若要保留 年月日 為一般欄位
# -----------------------------
s2330df_reset = s2330df.reset_index()

print("\n可另外使用 s2330df_reset（年月日為一般欄位）")
display(s2330df_reset.head())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 目前工作路徑： /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026
#
# === 檢查檔案是否存在 ===
# s2330d20260306.xlsx -> 存在
# 三大法人買賣超S2330台積電20260306.xlsx -> 存在
# 借券餘額S2330台積電20260306.xlsx -> 存在
# 當日沖銷S2330台積電20260306.xlsx -> 存在
# 融資融券S2330台積電20260306.xlsx -> 存在
#
# ========== 讀取檔案：s2330d20260306.xlsx ==========
# 原始 shape: (2720, 21)
# [s2330d20260306.xlsx] 日期欄位：年月日 -> 年月日，刪除無效日期 0 筆
# [s2330d20260306.xlsx] 刪除完全重複列：0 筆
# [s2330d20260306.xlsx] 整理後 shape: (2720, 21)
# [s2330d20260306.xlsx] 日期範圍: 2015-01-05 00:00:00 ~ 2026-03-06 00:00:00
#
# ========== 讀取檔案：三大法人買賣超S2330台積電20260306.xlsx ==========
# 原始 shape: (2720, 21)
# [三大法人買賣超S2330台積電20260306.xlsx] 日期欄位：年月日 -> 年月日，刪除無效日期 0 筆
# [三大法人買賣超S2330台積電20260306.xlsx] 刪除完全重複列：0 筆
# [三大法人買賣超S2330台積電20260306.xlsx] 整理後 shape: (2720, 21)
# [三大法人買賣超S2330台積電20260306.xlsx] 日期範圍: 2015-01-05 00:00:00 ~ 2026-03-06 00:00:00
#
# ========== 讀取檔案：借券餘額S2330台積電20260306.xlsx ==========
# 原始 shape: (2730, 15)
# [借券餘額S2330台積電20260306.xlsx] 日期欄位：年月日 -> 年月日，刪除無效日期 0 筆
# [借券餘額S2330台積電20260306.xlsx] 刪除完全重複列：0 筆
# [借券餘額S2330台積電20260306.xlsx] 整理後 shape: (2730, 15)
# [借券餘額S2330台積電20260306.xlsx] 日期範圍: 2015-01-05 00:00:00 ~ 2026-03-06 00:00:00
#
# ========== 讀取檔案：當日沖銷S2330台積電20260306.xlsx ==========
# 原始 shape: (2720, 14)
# [當日沖銷S2330台積電20260306.xlsx] 日期欄位：日期 -> 年月日，刪除無效日期 0 筆
# [當日沖銷S2330台積電20260306.xlsx] 刪除完全重複列：0 筆
# [當日沖銷S2330台積電20260306.xlsx] 整理後 shape: (2720, 14)
# [當日沖銷S2330台積電20260306.xlsx] 日期範圍: 2015-01-05 00:00:00 ~ 2026-03-06 00:00:00
#
# ========== 讀取檔案：融資融券S2330台積電20260306.xlsx ==========
# 原始 shape: (2719, 21)
# [融資融券S2330台積電20260306.xlsx] 日期欄位：年月日 -> 年月日，刪除無效日期 0 筆
# [融資融券S2330台積電20260306.xlsx] 刪除完全重複列：0 筆
# [融資融券S2330台積電20260306.xlsx] 整理後 shape: (2719, 21)
# [融資融券S2330台積電20260306.xlsx] 日期範圍: 2015-01-05 00:00:00 ~ 2026-03-06 00:00:00
#
# 成功載入資料表數量： 5
#
# ========== 開始合併 ==========
# 合併後 shape: (2732, 88)
#
# ========== 缺失值檢查（前20欄）==========
#                  欄位名稱  缺失值筆數  缺失比例(%)
# 79       margin_融資使用率     13     0.48
# 78      margin_融資增減比率     13     0.48
# 77    margin_融資增減(千元)     13     0.48
# 76     margin_融資增減(張)     13     0.48
# 68     margin_融資餘額(張)     13     0.48
# 69    margin_融資餘額(千元)     13     0.48
# 70     margin_融資買進(張)     13     0.48
# 71    margin_融資買進(千元)     13     0.48
# 84    margin_融券買進(千元)     13     0.48
# 85     margin_融券賣出(張)     13     0.48
# 86    margin_融券賣出(千元)     13     0.48
# 87   margin_融券現券償還(張)     13     0.48
# 83     margin_融券買進(張)     13     0.48
# 82    margin_融券餘額(千元)     13     0.48
# 81     margin_融券餘額(張)     13     0.48
# 80        margin_融資限額     13     0.48
# 75  margin_融資現金償還(千元)     13     0.48
# 74   margin_融資現金償還(張)     13     0.48
# 73    margin_融資賣出(千元)     13     0.48
# 72     margin_融資賣出(張)     13     0.48
# ========== 資料型態 ==========
# 年月日                 datetime64[ns]
# price_開盤價(元)               float64
# price_最高價(元)               float64
# price_最低價(元)               float64
# price_收盤價(元)               float64
#                          ...
# margin_融券買進(張)             float64
# margin_融券買進(千元)            float64
# margin_融券賣出(張)             float64
# margin_融券賣出(千元)            float64
# margin_融券現券償還(張)           float64
# Length: 88, dtype: object
#
# ========== 最終 s2330df ==========
# shape: (2732, 87)
#             price_開盤價(元)  price_最高價(元)  price_最低價(元)  price_收盤價(元)  \
# 年月日
# 2015-01-05      103.3608      103.3608      101.1538      102.6251
# 2015-01-06      101.1538      101.1538       97.8433       98.2111
# 2015-01-07       98.2111       99.3146       98.2111       98.5790
# 2015-01-08      100.4181      101.5216      100.0503      101.5216
# 2015-01-09       99.3146       99.6825       97.8433       98.5790
#
#             price_成交量(千股)  price_成交值(千元)  price_報酬率％  price_週轉率％  \
# 年月日
# 2015-01-05        32214.0      4459516.0     -1.0638      0.1242
# 2015-01-06        67649.0      9104346.0     -4.3011      0.2609
# 2015-01-07        43886.0      5887797.0      0.3745      0.1693
# 2015-01-08        42551.0      5839710.0      2.9851      0.1641
# 2015-01-09        61920.0      8308394.0     -2.8986      0.2388
#
#             price_流通在外股數(千股)  price_市值(百萬元)  ... margin_融資增減比率 margin_融資使用率  \
# 年月日                                          ...
# 2015-01-05        25929662.0      3617187.0  ...          2.22         0.32
# 2015-01-06        25929662.0      3461609.0  ...         13.26         0.36
# 2015-01-07        25929662.0      3474574.0  ...          4.70         0.38
# 2015-01-08        25929662.0      3578293.0  ...         -7.58         0.35
# 2015-01-09        25929662.0      3474574.0  ...         17.76         0.41
#
#             margin_融資限額  margin_融券餘額(張)  margin_融券餘額(千元)  margin_融券買進(張)  \
# 年月日
# 2015-01-05    6482398.0          4830.0        668616.90           457.0
# 2015-01-06    6482398.0          3493.0        470087.94          1432.0
# 2015-01-07    6482398.0          3350.0        449436.00           202.0
# 2015-01-08    6482398.0          3583.0        491730.92           170.0
# 2015-01-09    6482398.0          4025.0        540074.50           510.0
#
#             margin_融券買進(千元)  margin_融券賣出(張)  margin_融券賣出(千元)  margin_融券現券償還(張)
# 年月日
# 2015-01-05         63262.51           231.0         31977.33               0.0
# 2015-01-06        192718.56            95.0         12785.10               0.0
# 2015-01-07         27100.32            59.0          7915.44               0.0
# 2015-01-08         23330.80           403.0         55307.72               0.0
# 2015-01-09         68431.80           953.0        127873.54               1.0
#
# [5 rows x 87 columns]
# 已存檔：
# /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/s2330df_merged.csv
# /content/drive/MyDrive/Colab Notebooks/TEJ2026A/TEJ2026/s2330df_merged.xlsx
#
# 可另外使用 s2330df_reset（年月日為一般欄位）
#          年月日  price_開盤價(元)  price_最高價(元)  price_最低價(元)  price_收盤價(元)  \
# 0 2015-01-05      103.3608      103.3608      101.1538      102.6251
# 1 2015-01-06      101.1538      101.1538       97.8433       98.2111
# 2 2015-01-07       98.2111       99.3146       98.2111       98.5790
# 3 2015-01-08      100.4181      101.5216      100.0503      101.5216
# 4 2015-01-09       99.3146       99.6825       97.8433       98.5790
#
#    price_成交量(千股)  price_成交值(千元)  price_報酬率％  price_週轉率％  price_流通在外股數(千股)  \
# 0        32214.0      4459516.0     -1.0638      0.1242        25929662.0
# 1        67649.0      9104346.0     -4.3011      0.2609        25929662.0
# 2        43886.0      5887797.0      0.3745      0.1693        25929662.0
# 3        42551.0      5839710.0      2.9851      0.1641        25929662.0
# 4        61920.0      8308394.0     -2.8986      0.2388        25929662.0
#
#    ...  margin_融資增減比率 margin_融資使用率 margin_融資限額  margin_融券餘額(張)  \
# 0  ...           2.22         0.32   6482398.0          4830.0
# 1  ...          13.26         0.36   6482398.0          3493.0
# 2  ...           4.70         0.38   6482398.0          3350.0
# 3  ...          -7.58         0.35   6482398.0          3583.0
# 4  ...          17.76         0.41   6482398.0          4025.0
#
#    margin_融券餘額(千元)  margin_融券買進(張)  margin_融券買進(千元)  margin_融券賣出(張)  \
# 0        668616.90           457.0         63262.51           231.0
# 1        470087.94          1432.0        192718.56            95.0
# 2        449436.00           202.0         27100.32            59.0
# 3        491730.92           170.0         23330.80           403.0
# 4        540074.50           510.0         68431.80           953.0
#
#    margin_融券賣出(千元)  margin_融券現券償還(張)
# 0         31977.33               0.0
# 1         12785.10               0.0
# 2          7915.44               0.0
# 3         55307.72               0.0
# 4        127873.54               1.0
#
# [5 rows x 88 columns]

# %%
s2330df
# Out:
#             price_開盤價(元)  price_最高價(元)  price_最低價(元)  price_收盤價(元)  \
# 年月日
# 2015-01-05      103.3608      103.3608      101.1538      102.6251
# 2015-01-06      101.1538      101.1538       97.8433       98.2111
# 2015-01-07       98.2111       99.3146       98.2111       98.5790
# 2015-01-08      100.4181      101.5216      100.0503      101.5216
# 2015-01-09       99.3146       99.6825       97.8433       98.5790
# ...                  ...           ...           ...           ...
# 2026-03-02     1940.0000     1995.0000     1940.0000     1975.0000
# 2026-03-03     1970.0000     1980.0000     1935.0000     1935.0000
# 2026-03-04     1895.0000     1910.0000     1865.0000     1865.0000
# 2026-03-05     1940.0000     1960.0000     1895.0000     1900.0000
# 2026-03-06     1880.0000     1900.0000     1880.0000     1890.0000
#
#             price_成交量(千股)  price_成交值(千元)  price_報酬率％  price_週轉率％  \
# 年月日
# 2015-01-05        32214.0      4459516.0     -1.0638      0.1242
# 2015-01-06        67649.0      9104346.0     -4.3011      0.2609
# 2015-01-07        43886.0      5887797.0      0.3745      0.1693
# 2015-01-08        42551.0      5839710.0      2.9851      0.1641
# 2015-01-09        61920.0      8308394.0     -2.8986      0.2388
# ...                   ...            ...         ...         ...
# 2026-03-02        57404.0    113190016.0     -1.0025      0.2214
# 2026-03-03        54577.0    106561209.0     -2.0253      0.2105
# 2026-03-04        84647.0    159499070.0     -3.6176      0.3264
# 2026-03-05        56489.0    108468004.0      1.8767      0.2178
# 2026-03-06        34307.0     64781776.0     -0.5263      0.1323
#
#             price_流通在外股數(千股)  price_市值(百萬元)  ... margin_融資增減比率 margin_融資使用率  \
# 年月日                                          ...
# 2015-01-05        25929662.0      3617187.0  ...          2.22         0.32
# 2015-01-06        25929662.0      3461609.0  ...         13.26         0.36
# 2015-01-07        25929662.0      3474574.0  ...          4.70         0.38
# 2015-01-08        25929662.0      3578293.0  ...         -7.58         0.35
# 2015-01-09        25929662.0      3474574.0  ...         17.76         0.41
# ...                      ...            ...  ...           ...          ...
# 2026-03-02        25932525.0     51216736.0  ...          1.38         0.35
# 2026-03-03        25932525.0     50179435.0  ...         -1.26         0.34
# 2026-03-04        25932525.0     48364158.0  ...         -0.56         0.34
# 2026-03-05        25932525.0     49271797.0  ...          3.35         0.35
# 2026-03-06        25932525.0     49012471.0  ...          2.96         0.36
#
#             margin_融資限額  margin_融券餘額(張)  margin_融券餘額(千元)  margin_融券買進(張)  \
# 年月日
# 2015-01-05    6482398.0          4830.0        668616.90           457.0
# 2015-01-06    6482398.0          3493.0        470087.94          1432.0
# 2015-01-07    6482398.0          3350.0        449436.00           202.0
# 2015-01-08    6482398.0          3583.0        491730.92           170.0
# 2015-01-09    6482398.0          4025.0        540074.50           510.0
# ...                 ...             ...              ...             ...
# 2026-03-02    6483131.0           212.0        418020.26            21.0
# 2026-03-03    6483131.0           191.0        372924.12            21.0
# 2026-03-04    6483131.0           169.0        318444.13            27.0
# 2026-03-05    6483131.0           165.0        316821.53             9.0
# 2026-03-06    6483131.0           155.0        292682.59             7.0
#
#             margin_融券買進(千元)  margin_融券賣出(張)  margin_融券賣出(千元)  margin_融券現券償還(張)
# 年月日
# 2015-01-05         63262.51           231.0         31977.33               0.0
# 2015-01-06        192718.56            95.0         12785.10               0.0
# 2015-01-07         27100.32            59.0          7915.44               0.0
# 2015-01-08         23330.80           403.0         55307.72               0.0
# 2015-01-09         68431.80           953.0        127873.54               1.0
# ...                     ...             ...              ...               ...
# 2026-03-02         41407.67             8.0         15774.35               0.0
# 2026-03-03         41002.13             5.0          9762.41               5.0
# 2026-03-04         50875.69             5.0          9421.42               0.0
# 2026-03-05         17281.17             5.0          9600.65               0.0
# 2026-03-06         13217.92             0.0             0.00               3.0
#
# [2732 rows x 87 columns]

# %%
s2330df.columns
# Out:
# Index(['price_開盤價(元)', 'price_最高價(元)', 'price_最低價(元)', 'price_收盤價(元)',
#        'price_成交量(千股)', 'price_成交值(千元)', 'price_報酬率％', 'price_週轉率％',
#        'price_流通在外股數(千股)', 'price_市值(百萬元)', 'price_最後揭示買價', 'price_最後揭示賣價',
#        'price_報酬率-Ln', 'price_市值比重％', 'price_成交值比重％', 'price_成交筆數(筆)',
#        'price_本益比-TSE', 'price_本益比-TEJ', 'price_股價淨值比-TSE', 'price_股價淨值比-TEJ',
#        'major_外資買賣超(千股)', 'major_外資買賣超市值(百萬)', 'major_外資總投資股數(千股)',
#        'major_外資總投資市值(百萬)', 'major_投信買賣超(千股)', 'major_投信買賣超市值(百萬)',
#        'major_投信持股數(千股)', 'major_投信持股數市值(百萬)', 'major_自營買賣超(千股)',
#        'major_自營買賣超市值(百萬)', 'major_自營自行買賣超(千股)', 'major_自營自行買賣超(百萬)',
#        'major_自營避險買賣超(千股)', 'major_自營避險買賣超(百萬)', 'major_自營持股數(千股)',
#        'major_自營持股數市值(百萬)', 'major_合計買賣超(千股)', 'major_合計買賣超市值(百萬)',
#        'major_合計持股數(千股)', 'major_合計持股數市值(百萬)', 'borrow_balance_收盤價(元)',
#        'borrow_balance_合計-借券(千股)', 'borrow_balance_合計-還券(千股)',
#        'borrow_balance_合計-借券餘額(千股)', 'borrow_balance_合計-借券餘額市值(元)',
#        'borrow_balance_証交所-借券(千股)', 'borrow_balance_証交所-還券(千股)',
#        'borrow_balance_証交所-借券餘額(千股)', 'borrow_balance_証交所-借券餘額市值(元)',
#        'borrow_balance_證商/證金-借券(千股)', 'borrow_balance_證商/證金-還券(千股)',
#        'borrow_balance_證商/證金-借券餘額(千股)', 'borrow_balance_證商/證金借券餘額市值(元)',
#        'borrow_balance_市場別', 'day_trade_收盤價(元)', 'day_trade_成交量(千股)',
#        'day_trade_成交值(千元)', 'day_trade_當日沖銷交易總成交股數(千股)',
#        'day_trade_當日沖銷交易總成交股數占市場比重%', 'day_trade_當日沖銷交易總買進成交金額(千元)',
#        'day_trade_當日沖銷交易總買進成交金額占市場比重%', 'day_trade_當日沖銷交易總賣出成交金額(千元)',
#        'day_trade_當日沖銷交易總賣出成交金額占市場比重%', 'day_trade_報酬率％', 'day_trade_週轉率％',
#        'day_trade_當沖比重(資券互抵)', 'day_trade_現沖+當沖比重', 'margin_融資餘額(張)',
#        'margin_融資餘額(千元)', 'margin_融資買進(張)', 'margin_融資買進(千元)',
#        'margin_融資賣出(張)', 'margin_融資賣出(千元)', 'margin_融資現金償還(張)',
#        'margin_融資現金償還(千元)', 'margin_融資增減(張)', 'margin_融資增減(千元)',
#        'margin_融資增減比率', 'margin_融資使用率', 'margin_融資限額', 'margin_融券餘額(張)',
#        'margin_融券餘額(千元)', 'margin_融券買進(張)', 'margin_融券買進(千元)',
#        'margin_融券賣出(張)', 'margin_融券賣出(千元)', 'margin_融券現券償還(張)'],
#       dtype='object')

# %% [markdown]
# # GPT:
# 很好，姜老師。
# 您現在的資料是 **TEJ 台積電三大法人資料（majorTraded）**，欄位非常完整，包含：
#
# * 買賣超
# * 持股
# * 市值
# * 自營商拆分（自行 / 避險）
#
# 這已經是 **專業金融量化研究等級資料**。
#
# 以下我提供一套 **資深資料分析師標準版 Data Quality Check & Cleaning Pipeline**，可直接在 **Google Colab** 執行。
#
# ---
#
# # 📊 Step 0 — Colab 環境初始化
#
# ```python
# # ================================
# # TEJ Financial Data Analysis
# # Data Cleaning Pipeline
# # ================================
#
# from google.colab import drive
# drive.mount('/content/drive')
#
# import os
# BASE_PATH = "/content/drive/MyDrive/Colab Notebooks/TEJ2026A"
# os.chdir(BASE_PATH)
#
# print("Current Working Directory:", os.getcwd())
#
# # 基本套件
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# plt.style.use("seaborn-v0_8")
# ```
#
# ---
#
# # 📊 Step 1 — 基本資料結構檢查
#
# ```python
# print("===== Data Shape =====")
# print(majorTraded.shape)
#
# print("\n===== Column Names =====")
# print(majorTraded.columns)
#
# print("\n===== Data Types =====")
# print(majorTraded.dtypes)
#
# print("\n===== Preview =====")
# majorTraded.head()
# ```
#
# 專業分析師第一步一定確認：
#
# ```
# 資料筆數
# 欄位型態
# 欄位名稱
# ```
#
# ---
#
# # 📊 Step 2 — 日期格式處理
#
# TEJ資料通常是 **字串日期**
#
# ```python
# majorTraded['年月日'] = pd.to_datetime(majorTraded['年月日'])
#
# majorTraded = majorTraded.sort_values('年月日')
#
# majorTraded.set_index('年月日', inplace=True)
#
# majorTraded.head()
# ```
#
# 確認時間序列
#
# ```python
# print("Start Date:", majorTraded.index.min())
# print("End Date:", majorTraded.index.max())
# ```
#
# ---
#
# # 📊 Step 3 — 缺失值檢查
#
# ```python
# print("===== Missing Values =====")
#
# missing_table = majorTraded.isnull().sum().sort_values(ascending=False)
#
# missing_table
# ```
#
# 如果要看比例：
#
# ```python
# missing_ratio = (majorTraded.isnull().sum() / len(majorTraded))*100
#
# missing_df = pd.DataFrame({
#     "Missing Count": majorTraded.isnull().sum(),
#     "Missing Ratio %": missing_ratio
# })
#
# missing_df.sort_values("Missing Ratio %", ascending=False)
# ```
#
# ---
#
# # 📊 Step 4 — 重複資料檢查
#
# ```python
# duplicates = majorTraded.index.duplicated().sum()
#
# print("Duplicate Date Rows:", duplicates)
# ```
#
# 如果存在：
#
# ```python
# majorTraded = majorTraded[~majorTraded.index.duplicated()]
# ```
#
# ---
#
# # 📊 Step 5 — 數值型欄位確認
#
# 有些 TEJ 匯出會變成 object
#
# ```python
# majorTraded.select_dtypes(include='object').columns
# ```
#
# 若需要轉型：
#
# ```python
# cols = majorTraded.columns
#
# majorTraded[cols] = majorTraded[cols].apply(pd.to_numeric, errors='coerce')
# ```
#
# ---
#
# # 📊 Step 6 — 基本統計描述
#
# ```python
# majorTraded.describe().T
# ```
#
# 這可以看出：
#
# ```
# 平均
# 標準差
# 最大
# 最小
# ```
#
# ---
#
# # 📊 Step 7 — 極端值檢查（Outlier Detection）
#
# 金融資料非常重要的一步
#
# ```python
# plt.figure(figsize=(14,6))
#
# sns.boxplot(data=majorTraded[['外資買賣超(千股)',
#                               '投信買賣超(千股)',
#                               '自營買賣超(千股)']])
#
# plt.title("Institutional Net Buy/Sell Distribution")
# plt.show()
# ```
#
# ---
#
# # 📊 Step 8 — 三大法人分布圖
#
# ```python
# majorTraded[['外資買賣超(千股)',
#               '投信買賣超(千股)',
#               '自營買賣超(千股)']].hist(
#     figsize=(14,6),
#     bins=50
# )
#
# plt.suptitle("Distribution of Institutional Trading")
# plt.show()
# ```
#
# ---
#
# # 📊 Step 9 — 相關性分析
#
# ```python
# corr = majorTraded.corr()
#
# plt.figure(figsize=(12,10))
#
# sns.heatmap(
#     corr,
#     cmap="coolwarm",
#     center=0
# )
#
# plt.title("Correlation Matrix of Institutional Trading")
# plt.show()
# ```
#
# ---
#
# # 📊 Step 10 — 時間序列視覺化
#
# ```python
# plt.figure(figsize=(14,6))
#
# plt.plot(majorTraded.index, majorTraded['外資買賣超(千股)'], label='Foreign')
# plt.plot(majorTraded.index, majorTraded['投信買賣超(千股)'], label='Trust')
# plt.plot(majorTraded.index, majorTraded['自營買賣超(千股)'], label='Dealer')
#
# plt.legend()
#
# plt.title("TSMC Institutional Net Buy/Sell")
#
# plt.show()
# ```
#
# ---
#
# # 📊 Step 11 — 建立法人合計指標
#
# 這是量化研究常用
#
# ```python
# majorTraded['法人買賣超(千股)'] = (
#     majorTraded['外資買賣超(千股)'] +
#     majorTraded['投信買賣超(千股)'] +
#     majorTraded['自營買賣超(千股)']
# )
# ```
#
# ---
#
# # 📊 Step 12 — 清理後資料存檔
#
# ```python
# clean_path = f"{BASE_PATH}/TSMC_major_trading_clean.csv"
#
# majorTraded.to_csv(clean_path)
#
# print("Saved:", clean_path)
# ```
#
# ---
#
# # 🎯 專業分析師下一步建議
#
# 有了這份資料，我會建議您做 **三個高價值分析**：
#
# ### 1️⃣ 法人累積部位
#
# ```
# 外資累積持股
# 投信累積持股
# 自營商累積持股
# ```
#
# 可以看到 **長期資金布局**
#
# ---
#
# ### 2️⃣ 法人 vs 股價
#
# 建立
#
# ```
# 法人買超 → 股價漲跌
# ```
#
# 做 **lead-lag analysis**
#
# ---
#
# ### 3️⃣ 機器學習預測
#
# 用
#
# ```
# 外資
# 投信
# 自營
# ```
#
# 預測
#
# ```
# 隔日股價
# ```
#
# 模型：
#
# ```
# XGBoost
# RandomForest
# LightGBM
# ```
#
# ---
#
# 如果您願意，我可以直接幫您寫一份 **金融研究等級的 Colab Notebook**：
#
# # 🚀 台積電三大法人量化分析 AI Notebook
#
# 包含：
#
# 1️⃣ **EDA 30圖**
# 2️⃣ **法人累積行為分析**
# 3️⃣ **法人領先指標**
# 4️⃣ **Rolling Flow Analysis**
# 5️⃣ **Machine Learning 預測股價**
# 6️⃣ **SHAP解釋模型**
#
# 這一份其實是 **EMBA金融AI課程非常好的案例教材**。
